# %%
# for mongodb
import pymongo

# normal stuff
import pandas as pd
import numpy as np
import cPickle as pickle
import matplotlib.pyplot as plt
# %matplotlib inline

from collections import defaultdict, Counter
import string
import re
import codecs

# nltk
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# gensim
import gensim
from gensim.corpora.dictionary import Dictionary
from gensim.models.tfidfmodel import TfidfModel
from gensim.models.ldamodel import LdaModel
from gensim.models.ldamulticore import LdaMulticore
from gensim import similarities

# spacy
import spacy
# python -m spacy download en ## to download english model for spacy, do in cmd
# Out:
# C:\ProgramData\Anaconda2\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "
# C:\ProgramData\Anaconda2\lib\site-packages\gensim\utils.py:860: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
# load spacy english model
nlp_spacy = spacy.load('en')

# %% [markdown]
# ## Connect to Dramabeans database
# Connect to the Dramabeans database set up in p02-scrape-dramabeans.ipynb

# %%
# "C:\Program Files\MongoDB\Server\3.6\bin\mongod.exe" --dbpath "D:\Documents\Heidi\mongodb\data"

# Connection to Mongo DB
try:
    client = pymongo.MongoClient()
    print "Hooray, we have connected to MongoDB successfully!"
except pymongo.errors.ConnectionFailure, e:
    print "Could not connect to MongoDB: %s" % e
# Out:
# Hooray, we have connected to MongoDB successfully!

# %% [markdown]
# ### clean up database
#
# so that we don't mess up the original scraped data, create a fresh working copy. Connect to this copy, clean up issues. There are a total of 386 shows in the database, and a total of 4,975 episodes worth of data.

# %%
# make a new copy to work on
# client.admin.command('copydb', fromdb='dramabeans_v2', todb='dramabeans_v3')

# %%
# connect to the dramabeans database
print client.database_names()
db = client.dramabeans_v4
# Out:
# [u'admin', u'config', u'dramabeans_v2', u'dramabeans_v3', u'dramabeans_v4', u'local', u'raw_dramabeans']

# %%
# # clean up the replicated drama - same drama, 2 names
# for doc in db[u'who are you—school 2015'].find():
#     db[u'who are you–school 2015'].insert_one(doc)
    
# db.drop_collection(u'who are you–school 2015')

# %%
# collection names
print 'No. of shows: {}'.format(len(db.collection_names()))
# Out:
# No. of shows: 386

# %%
# total number of documents (aka. total number of episodes of data)
counter = 0
for collection in db.collection_names():
    counter += db[collection].count()
print 'Total number of documents: {}'.format(counter)
# Out:
# Total number of documents: 4975

# %%
# total number of comments
num_comments = 0
for collection in db.collection_names():
    for ep in db[collection].find():
        num_comments += ep['Num_Comments']
print 'Total number of comments in database: {}'.format(num_comments)
# Out:
# Total number of comments in database: 645188

# %%
# put all show names into a list
shownames = db.collection_names()
# print shownames

# pick 3 shows to do initial playing
# shownames = [u'circle', u'weightlifting fairy kim bok-ju', u'oh hae-young again']

# randomly pick some shows
num_shows = 386
np.random.seed(58)
show_ids = np.random.choice(range(len(db.collection_names())), size=num_shows, replace=False)
shownames = [show for i, show in enumerate(shownames) if i in show_ids]

print shownames
# Out:
# [u'a gentleman\u2019s dignity', u'last', u'green rose', u'joseon x-files', u'drinking solo', u'love & marriage', u'dream', u'manny', u'smile', u'dream high 2', u'you from another star', u'i need romance', u'jang ok-jung, live by love', u'jugglers', u'splish splash love', u'medical top team', u'style', u'i\u2019m not a robot', u'witch amusement', u'ma boy', u'i am legend', u'when a man loves', u'the moon that embraces the sun', u'i miss you', u'school 2013', u'pied piper', u'the lonely shining goblin', u'man who dies to live', u'miss ripley', u'arang and the magistrate', u'beautiful gong shim', u'ad genius lee tae-baek', u'painter of the wind', u'she was pretty', u'five fingers', u'answer me 1994', u'boys before flowers', u'story of a man', u'fashion king', u'history of the salaryman', u'bride of the water god 2017', u'radiant office', u'uncontrollably fond', u'gu family book', u'wanted', u'woman with a suitcase', u'nothing to lose', u'heart to heart', u'hwarang', u'age of youth', u'iris 2', u'padam padam', u'my girlfriend is a gumiho', u'level 7 civil servant', u'operation proposal', u'romance hunter', u'twelve men in a year', u'prosecutor princess', u'modern farmer', u'rebel: thief who stole the people', u'w\u2013two worlds', u'neighborhood lawyer jo deul-ho', u'oh hae-young again', u'beethoven virus', u'i hear your voice', u'age of feeling', u'alice in cheongdam-dong', u'invincible lee pyeong-gang', u'faith', u'chicago typewriter', u'marriage not dating', u'crime squad', u'age of youth 2', u'high school king of savvy', u'air city', u'me too, flower', u'personal taste', u'signal', u'best love', u'the story of hyang dan', u'romantic doctor teacher kim', u'moon lovers: scarlet heart ryeo', u'criminal minds', u'could we love', u'seven day queen', u'poseidon', u'mystery queen', u'smart prison living', u'thousand day promise', u'incarnation of money', u'doctors', u'let\u2019s eat 2', u'love rain', u'master\u2013god of noodle', u'suspicious partner', u'strongest deliveryman', u'jealousy incarnate', u'goodbye mr. black', u'moorim school', u'haeundae lovers', u'mirror of the witch', u'my sassy girl', u'oh my geum-bi', u'cantabile tomorrow', u'sly and single again', u'whisper', u'sons of sol pharmacy', u'shut up: flower boy band', u'emergency couple', u'police unit 38', u'bubblegum', u'wild romance', u'entertainer', u'mrs. cop', u'scent of a woman', u'witch\u2019s romance', u'insoon is pretty', u'hanbando / korean peninsula', u'mask', u'secret door', u'shark', u'special affairs team ten', u'vampire prosecutor 2', u'village: secret of achiara', u'my sweet seoul', u'flowers for my life', u'd-day', u'go back spouses', u'my princess', u'jeon woo-chi', u'missing noir m', u'second to last love', u'third ward', u'memory', u'mad dog', u'girl who sees smells', u'three musketeers', u'flower boy next door', u'wish upon a star', u'the musical', u'one more happy ending', u'trot lovers', u'perfect wife', u'standby', u'answer me 1988', u'dr. frost', u'dr. jin', u'liar game', u'mixed-up investigative agency', u'baby-faced beauty', u'entourage', u'dating agency cyrano', u'girl k', u'playful kiss', u'master\u2019s sun', u'mi-rae\u2019s choice', u'beautiful mind', u'you\u2019re all surrounded', u'awl', u'records of a night watchman', u'goong s', u'pinocchio', u'dal ja\u2019s spring', u'the best hit', u'orange marmalade', u'monstar', u'what\u2019s up', u'sirius', u'i remember you', u'manhole', u'conspiracy in the court', u'que sera sera', u'god\u2019s gift \u2013 14 days', u'the k2', u'god of study', u'rescue me', u'nine', u'spy', u'who are you', u'i need romance 3', u'hwayugi', u'tree with deep roots', u'descended from the sun', u'bring it on, ghost', u'the time i\u2019ve loved you', u'wonderful season', u'chuno', u'city hunter', u'fated to love you', u'lookout', u'masked prosecutor', u'the world they live in', u'the good wife', u'i do, i do', u'gap-dong', u'high school: love on', u'dr. champ', u'iron man', u'remember\u2014son\u2019s war', u'introverted ...

# %% [markdown]
# ## build corpus
# Build a corpus where each entry is the recaps of all the episodes of that show.

# %%
# put all the recaps into a dictionary
recaps = defaultdict(str)
for show in shownames:
    for doc in db[show].find():
        recaps[show] += doc['Recap']

recaps['circle']
# Out:
# u'The two worlds have collided, and the disparate timelines have merged. Now, all that remains is for our heroes to find a way to defeat the all-powerful Human B and escape Smart Earth with their lives and memories intact. Tall order? Maybe. But this group of loyal, stubborn friends have stuck to their guns through years of loneliness and oppression. Now that they\u2019re together, nothing will stop them from giving the evil corporation running Smart Earth a run for their money.  FINAL EPISODE RECAP  Running from Professor Park and his goons, Woo-jin comes out of the woods and stumbles straight into the path of an oncoming car. It hits him at high speed, and he goes hurtling through the air before falling hard on the asphalt. As blood pools under his head, he reaches toward the broken star as he thinks of his brother and Jung-yeon. The alien cube that powered the device dims as the life ebbs out of Woo-jin. Sometime later, Woo-jin lies in a coma in a hospital room, the cube in a glass box on the side table. Professor Park stares at his unmoving body, while Sunbae Lee sits by the door with his head clasped in his hands. The surgeon who operated on Bum-gyun and Min-young arrives and tells the professor that it\u2019s uncertain whether either will wake up any time soon, or if they will even retain their memories.  Min-young wakes up though, and the first person she asks about is Bum-gyun. Chief Hong takes her to the boy and tells her that they don\u2019t know when or if he will ever wake up. Leaving her by Bum-gyun\u2019s side, Chief Hong emerges from the room and receives an email from Woo-jin. In it, Woo-jin tells Chief Hong to give Bum-gyun the memory footage stored in a hard drive, in case he doesn\u2019t regain his own. Chief Hong finds the external hard drive in Woo-jin\u2019s backpack and tries to call Woo-jin, only to hear his voicemail. Just then, Chief Hong gets a call from his superior telling him that he\u2019s been transferred to the Cyber Crimes Unit.  Min-young runs out of the hospital room and says that she also just received a pre-scheduled email from Woo-jin that told her he wouldn\u2019t be able to return. \u201cI feel like something bad happened to Woo-jin,\u201d Chief Hong concludes worriedly. Jung-yeon gets to a safe place and plugs in her phone to her laptop. Going through the images on her phone, she comes across the one she and Woo-jin had laughed over. Remembering how she\u2019d told him to smile more, Jung-yeon tears up in the present. Suddenly, an email notification pops up, and Jung-yeon gets her own pre-scheduled email from Woo-jin. In it is another video of Woo-jin, but this time, he says that if he isn\u2019t back by now, then his plan must have failed. He tells her to hide and never look for him.  Even as Jung-yeon shakes her head, Woo-jin says he knows that it would go against the grain for her. But he adds that if she doesn\u2019t protect herself, then she would be wasting his sacrifice as well as Byul\u2019s. As tears stream down Jung-yeon\u2019s face, Video Woo-jin tells her that he\u2019ll definitely come back to her and Bum-gyun \u2014 it\u2019ll just take him a little longer than he\u2019d expected. \u201cWait just a little bit longer,\u201d Woo-jin says, adding a small, reassuring smile. We return to 2037, and to the scene that ended the last episode as Woo-jin remembers what he\u2019d said to Bum-gyun back in the hospital room: \u201cHyung, I\u2019m scared. I\u2019ll.. be back.\u201d  With tears streaming down his face, Joon-hyuk asks if Woo-jin was leaving to meet Professor Park when he said those words to him. \u201cWere you going to trade my surgery for dad\u2019s research? Is that what you were scared of?\u201d Joon-hyuk asks. Sobbing with grief, Joon-hyuk apologizes for letting Woo-jin go alone and pulls his little brother into a hug. While Woo-jin resists at first, still believing himself to be a clone, his face crumples up as he hugs Joon-hyuk back. Dong-soo runs into the church an ...

# %% [markdown]
# ## tokenisation
# Tokenize the corpus

# %%
# tokenize
shows = recaps.keys()

tokenized = [nltk.tokenize.word_tokenize(recap)
             for recap in recaps.values()]

# %% [markdown]
# ## NER
#
# There is a need to remove the character names, otherwise all the topics identified will just contain names. Use Named Entity Recognition (NER) to form a list of stop words to exclude for each show. Include caps so that we filter out "Young" (Korean name) but not "young".
#
# Since training an NER is a project in itself (have to manually identify NER in string), try some out-of-the-box NERs.
#
# Models:
# 1. nltk: ne_chunk (nltk's current best NER)
# 2. spaCy

# %% [markdown]
# ### NER using NLTK

# %%
# tokenize
shows = recaps.keys()

tokenized = [nltk.tokenize.word_tokenize(recap.encode('utf-8').decode(errors='ignore'))
             for recap in recaps.values()]
# print shows
# print len(tokenized)
# print len(tokenized[0]), len(tokenized[1])
tagged = [nltk.pos_tag(recap) for recap in tokenized]

# %%
# because the NLTK NER cannot handle special characters, have to remove them
weird_utf =  [u'\u2014', u'\u2019', u'\u201c', u'\u201d', u'\u2665']
tagged_clean = [[(word_tup[0].encode('utf-8').decode(), word_tup[1]) for word_tup in recap
               if word_tup[0] not in weird_utf]
               for recap in tagged ]
tagged_clean[0]
entities = [[nltk.chunk.ne_chunk(recap, binary=False)] for recap in tagged_clean] 
# if binary=False, classify into GPE, PERSON, ORGANIZATION... etc.

# save named entities in list, all_ne_nltk
all_ne_nltk = []
for entity in entities:
    set_names = []
    for sent in entity:
        for chunk in sent:
            if hasattr(chunk, 'label') and chunk.label() == 'PERSON':
                set_names.append([ne for tree in chunk for ne in tree])
    all_ne_nltk.append( set([word.lower() for item in set_names for word in item if word != 'NNP']))
    
all_ne_nltk
# Out:
# [{u'adams',
#   u'adobe',
#   u'afterward',
#   u'alas',
#   u'amanda',
#   u'arts',
#   u'baby',
#   u'bernard',
#   u'boy',
#   u'bynes',
#   u'chi',
#   u'cut',
#   u'daehan',
#   u'delete',
#   u'dont',
#   u'download',
#   u'duff',
#   u'dumb',
#   u'fantastic',
#   u'flash',
#   u'funny',
#   u'gahhh',
#   u'grar',
#   u'hes',
#   u'highs',
#   u'hilary',
#   u'idiot',
#   u'ill',
#   u'irene',
#   u'irenes',
#   u'itll',
#   u'jang',
#   u'kang',
#   u'kim',
#   u'ma',
#   u'nearby',
#   'nnps',
#   'nns',
#   u'omg',
#   u'paparazzo',
#   u'pesky',
#   u'player',
#   u'reporter',
#   u'schoolyard',
#   u'scroll',
#   u'shes',
#   u'snerk',
#   u'so-hyun',
#   u'sorry',
#   u'stab',
#   u'tackle',
#   u'tackles',
#   u'thats',
#   u'thinkin',
#   u'tooniverse',
#   u'trio',
#   u'twinkle',
#   u'uncle',
#   u'wait',
#   u'which'},
#  {u'administration',
#   u'adobe',
#   u'adorbs',
#   u'adult',
#   u'afterward',
#   u'ahhh',
#   u'always',
#   u'angry',
#   u'anyhow',
#   u'are',
#   u'aww',
#   u'b',
#   u'bad',
#   u'blearily',
#   u'cant',
#   u'captain',
#   u'ceo',
#   u'chairman',
#   u'club',
#   u'coldplay',
#   u'cosmetics',
#   u'cue',
#   u'cut',
#   u'damaged',
#   u'did',
#   u'didnt',
#   u'dinner',
#   u'director',
#   u'doctor',
#   u'does',
#   u'dong-wook',
#   u'dont',
#   u'download',
#   u'dream',
#   u'drug',
#   u'drunk',
#   u'dude',
#   u'due',
#   u'eleanor',
#   u'elsa',
#   u'fine',
#   u'flash',
#   u'flustered',
#   u'god',
#   u'good',
#   u'group',
#   u'groups',
#   u'hah',
#   u'haha',
#   u'hahaha',
#   u'hahahashe',
#   u'heart',
#   u'hed',
#   u'heh',
#   u'hehe',
#   u'hell',
#   u'hermia',
#   u'hermiaif',
#   u'hermias',
#   u'hes',
#   u'hmmm',
#   u'hook',
#   u'howd',
#   u'human',
#   u'hyungnim',
#   u'hyungnims',
#   u'ill',
#   u'im',
#   u'imagine',
#   u'ive',
#   u'jaebum',
#   u'james',
#   u'jang',
#   u'jeez',
#   u'jesus',
#   u'ji-hyun',
#   'jj',
#   u'jo',
#   u'joon-hee',
#   u'jos',
#   u'jung',
#   u'kang',
#   u'kangs',
#   u'kim',
#   u'kyun-sung',
#   u'lee',
#   u'little',
#   u'luckily',
#   u'ma',
#   u'madam',
#   u'mars',
#   u'mas',
#   u'min',
#   u'min-ho',
#   u'mom',
#   u'mr.',
#   u'murderer',
#   u'night',
#   'nn',
#   u'noh',
#   u'nohs',
#   u'oh',
#   u'ohhh',
#   u'ohs',
#   u'ok-hyun',
#   u'okay',
#   u'only',
#   u'ooh',
#   u'oooh',
#   u'pan',
#   u'papa',
#   u'park',
#   u'paul',
#   u'peter',
#   u'pfft',
#   u'plan',
#   u'player',
#   u'point',
#   u'poor',
#   u'pumpkin',
#   u'puppy',
#   u'ricky',
#   u'roosevelt',
#   u'sad',
#   u'save',
#   u'shes',
#   u'si-hwan',
#   u'someone',
#   u'soon',
#   u'soon-jung',
#   u'strange',
#   u'superman',
#   u'takedown',
#   u'thats',
#   u'thus',
#   u'time',
#   u'tomorrow',
#   u'toy',
#   u'truly',
#   u'upon',
#   u'vietnam',
#   u'wait',
#   u'wamp',
#   u'weiner',
#   u'wendy',
#   u'whats',
#   u'which',
#   u'whoa',
#   u'wigo',
#   u'women',
#   u'word',
#   u'worried',
#   u'wtf',
#   u'yoon',
#   u'yoons',
#   u'youre'},
#  {u'accountant',
#   u'afterward',
#   u'ahn',
#   u'air',
#   u'airs',
#   u'alarmed',
#   u'almost',
#   u'amid',
#   u'angry',
#   u'anniversary',
#   u'annoyed',
#   u'bang',
#   u'bangs',
#   u'beom-joon',
#   u'breathe',
#   u'bully',
#   u'byeon',
#   u'cars',
#   u'cha',
#   u'chairiman',
#   u'chairman',
#   u'chas',
#   u'cheetah',
#   u'chi-hoon',
#   u'choi',
#   u'cockroach',
#   u'constructions',
#   u'crazy',
#   u'customers',
#   u'detective',
#   u'director',
#   u'dog',
#   u'dogs',
#   u'dong-chul',
#   u'dong-yoon',
#   u'dont',
#   u'downstairs',
#   u'drink',
#   u'elsewhere',
#   u'enraged',
#   u'eun-joo',
#   u'eun-joon',
#   u'farm',
#   u'father',
#   u'flustered',
#   u'frantic',
#   u'gebauer',
#   u'get',
#   u'go',
#   u'gohang',
#   u'gosh',
#   u'group',
#   u'ha-ri',
#   u'haha',
#   u'han',
#   u'han-dong',
#   u'heinrich',
#   u'heinrichs',
#   u'hell',
#   u'hello',
#   u'help',
#   u'hes',
#   u'hong-joo',
#   u'hood',
#   u'how',
#   u'hq',
#   u'hyun',
#   u'hyun-gi',
#   u'hyung',
#   u'id',
#   u'ill',
#   u'im',
#   u'inside',
#   u'insurance',
#   u'island',
#   u'isnt',
#   u'its',
#   u'jae-soo',
#   u'jan',
#   u'jang',
#   u'jeju',
#   u'jh',
#   u'jin',
#   u'jin-chul',
#   'jj',
#   u'jo',
#   u'jonas',
#   u'jong-gu',
#   u'joo',
#   u'joo-shik',
#   u'joos',
#   u'jos',
#   u'juhan',
#   u'kang',
#   u'kang-woo',
#   u'kim',
#   u'korea',
#   u'kwon',
#   u'lafora',
#   u'law',
#   u'lawyer',
#   u'lee',
#   u'lee.the',
#   u'lees',
#   u'lets',
#   u'mad',
#   u'manager',
#   u'manger',
#   u'min-joon',
#   u'mom',
#   u'mr.',
#   u'ms.',
#   u'na',
#   u'nearby',
#   'nn',
#   'nns',
#   u'noo-ri',
#   u'nurse',
#   u'oh',
#   u'ohn',
#   u'ohs',
#   u'once',
#   u'oppa',
#   u'outside',
#   u'oxygen',
#   u'park',
#   u'parks',
#   u'pentium',
#   u'pffft',
#   u'phones',
#   u'pilot',
#   u'player',
#   u'please',
#   u'poison',
#   u'poor',
#   u'professor',
#   u'prosecutor',
#   'prp$',
#   u'punk',
#   u'puppy',
#   u'reporter',
#   u'robin',
#   u'sang-min',
#   u'sang-myun',
#   u'satisfied',
#   u'second',
#   u'seong-jin',
#   u'shin',
#   u'shins',
#   u'soo-oh',
#   u'soo-ohs',
#   u'soon-jung',
#   u'spaniel',
#   u'stop',
#   u'sung-ho',
#   u'suspicious',
#   u'taeyang',
#   u'taeyangs',
#   u'taken',
#   u'tap',
#   u'traitor',
#   u'upstairs',
#   u'were',
#   u'where',
#   u'will',
#   u'wrap',
#   u'yong-joo',
#   u'youll',
#   u'youre'},
#  {u'a-z',
#   u'achilles',
#   u'adobe',
#   u'afterward',
#   u'again',
#   u'angry',
#   u'answer',
#   u'armageddon',
#   u'athletic',
#   u'awkward',
#   u'aww',
#   u'awww',
#   u'bad',
#   u'baek',
#   u'baeks',
#   u'beautiful',
#   u'better',
#   u'bin',
#   u'boy',
#   u'cant',
#   u'cha',
#   u'charles',
#   u'cheeky',
#   u'coach',
#   u'coachs',
#   u'competition',
#   u'cut',
#   u'cute',
#   u'dad',
#   u'dads',
#   u'damn',
#   u'dan-mu',
#   u'daniel',
#   u'daniels',
#   u'darn',
#   u'darth',
#   u'dawson',
#   u'daww',
#   u'destiny',
#   u'director',
#   u'doc',
#   u'docs',
#   u'dong-gun',
#   u'dont',
#   u'double',
#   u'dough',
#   u'download',
#   u'drama',
#   u'dream',
#   u'dude',
#   u'dyou',
#   u'eeeep',
#   u'eugene',
#   u'eun-gyul',
#   u'everyone',
#   u'excuse',
#   u'fanclub',
#   u'festival',
#   u'first',
#   u'flash',
#   u'flashback',
#   u'gah',
#   u'genie',
#   u'get',
#   u'girl',
#   u'girlfriend',
#   u'girls',
#   u'go',
#   u'god',
#   u'good',
#   u'goodbye',
#   u'grandmas',
#   u'grandpa',
#   u'grungy',
#   u'gu',
#   u'guess',
#   u'hahaha',
#   u'hanna',
#   u'hannas',
#   u'happy',
#   u'headlines',
#   u'heads',
#   u'headsno2',
#   u'heart',
#   u'hed',
#   u'heehee',
#   u'heh',
#   u'hell',
#   u'hes',
#   u'high',
#   u'hmm',
#   u'holton',
#   u'holtons',
#   u'hong',
#   u'humor',
#   u'hurry',
#   u'hyun-jae',
#   u'hyun-woo',
#   u'hyung',
#   u'ian',
#   u'ill',
#   u'im',
#   u'imaginary',
#   u'inside',
#   u'is',
#   u'ive',
#   u'jae-hee',
#   u'jang',
#   u'jay',
#   u'jealous',
#   u'ji-sung',
#   'jj',
#   u'john',
#   u'jong-min',
#   u'julien',
#   u'just',
#   u'kang',
#   u'ki',
#   u'killer',
#   u'kim',
#   u'kiss',
#   u'later',
#   u'lee',
#   u'lees',
#   u'lesson',
#   u'life',
#   u'love',
#   u'martial',
#   u'master',
#   u'me',
#   u'meet',
#   u'min',
#   u'miss',
#   u'mmhm',
#   u'mom',
#   u'moms',
#   u'mr.',
#   u'nationals',
#   'nn',
#   'nns',
#   u'noona',
#   u'nooo',
#   u'nude',
#   u'oh',
#   u'okay',
#   u'omg',
#   u'omo',
#   u'onew',
#   u'ooh',
#   u'oops',
#   u'oppa',
#   u'oppas',
#   u'outside',
#   u'park',
#   u'pd-nim',
#   u'person',
#   u'pfft',
#   u'phew',
#   u'player',
#   u'please',
#   u'poor',
#   u'princess',
#   u'problem',
#   u'ratings',
#   u'rawr',
#   u'reason',
#   u'reporter',
#   u'rita',
#   u'rules',
#   u'sangchu',
#   u'selca',
#   u'seol',
#   u'seoul',
#   u'serin',
#   u'shes',
#   u'shooter',
#   u'skeeter',
#   u'snip',
#   u'someone',
#   u'son',
#   u'soon',
#   u'sorry',
#   u'stand',
#   u'stay',
#   u'stuck',
#   u'style',
#   u'sulli',
#   u'sure',
#   u'suspicious',
#   u'swoon',
#   u'tae-joon',
#   u'taken',
#   u'talk',
#   u'target',
#   u'teacher',
#   u'tears',
#   u'teehee',
#   u'tension',
#   u'thank',
#   u'thats',
#   u'trio',
#   u'trouble',
#   u'truth',
#   u'up',
#   u'vader',
#   u'virus',
#   u'vitamin',
#   u'voice',
#   u'wait',
#   u'waitaminit',
#   u'water',
#   u'were',
#   u'whats',
#   u'where',
#   u'whether',
#   u'whhhattttt',
#   u'which',
#   u'wholl',
#   u'whoops',
#   u'will',
#   u'won',
#   u'wrong',
#   u'yang',
#   u'yangs',
#   u'yips',
#   u'youll',
#   u'youre',
#   u'youve'},
#  {u'a',
#   u'aaaaack',
#   u'adobe',
#   u'agent',
#   u'ahaha',
#   u'ahhhhh',
#   u'ahn',
#   u'ahns',
#   u'ajusshi',
#   u'andre',
#   u'arang',
#   u'arg',
#   u'argh',
#   u'arm',
#   u'awwww',
#   u'awwwww',
#   u'baby',
#   u'back',
#   u'bad',
#   u'bang',
#   u'bartender',
#   u'basically',
#   u'bastard',
#   u'beautiful',
#   u'bell',
#   u'bingo',
#   u'blood',
#   u'bloods',
#   u'boss',
#   u'boy',
#   u'boys',
#   u'brain',
#   u'bromantic',
#   u'byung-soo',
#   u'chan',
#   u'chesty',
#   u'choong-gu',
#   u'chul-ho',
#   u'chul-oh',
#   u'chyron',
#   u'club',
#   u'cmon',
#   u'congressman',
#   u'cop',
#   u'cops',
#   u'coroner',
#   u'crackpot',
#   u'crap',
#   u'crazy',
#   u'crazys',
#   u'creepy',
#   u'cue',
#   u'cut',
#   u'dad',
#   u'dada',
#   u'daddy',
#   u'dads',
#   u'dae',
#   u'damn',
#   u'dangerous',
#   u'dead',
#   u'death',
#   u'detective',
#   u'diamonds',
#   u'director',
#   u'doc',
#   u'doesnt',
#   u'dogs',
#   u'dont',
#   u'double',
#   u'download',
#   u'dream',
#   u'dude',
#   u'dun',
#   u'dyou',
#   u'eeee',
#   u'eeeeek',
#   u'eeep',
#   u'eek',
#   u'eyes',
#   u'fight',
#   u'flash',
#   u'flashback',
#   u'gabriel',
#   u'gah',
#   u'gee',
#   u'geez',
#   u'go',
#   u'gong',
#   u'gongs',
#   u'good',
#   u'gps',
#   u'grandfather',
#   u'grandpa',
#   u'grandpas',
#   u'groan',
#   u'gulp',
#   u'hae-ri',
#   u'haha',
#   u'hahaha',
#   u'hak-bum',
#   u'han',
#   u'hannibal',
#   u'hart',
#   u'hed',
#   u'hell',
#   u'hello',
#   u'heo',
#   u'hero',
#   u'heroine',
#   u'hes',
#   u'hey',
#   u'holy',
#   u'hooded',
#   u'hoody',
#   u'hoon',
#   u'hoons',
#   u'how',
#   u'huh',
#   u'hyun',
#   u'hyun-sook',
#   u'hyung',
#   u'hyung-kwan',
#   u'ick',
#   u'id',
#   u'ill',
#   u'im',
#   u'inside',
#   u'instinct',
#   u'j',
#   u'jang',
#   u'ji-hye',
#   'jj',
#   u'jo',
#   u'joo',
#   u'joo-hyuk',
#   u'joon-sung',
#   u'jung',
#   u'kids',
#   u'killer',
#   u'kim',
#   u'kims',
#   u'kyo-min',
#   u'lady',
#   u'larue',
#   u'lawyer',
#   u'lecter',
#   u'lee',
#   u'life',
#   u'little',
#   u'lol',
#   u'love',
#   u'luck',
#   u'mad',
#   u'man',
#   u'min',
#   u'min-young',
#   u'mina',
#   u'minas',
#   u'miss',
#   u'mom',
#   u'move',
#   u'movie',
#   u'mr.',
#   u'narrator',
#   u'next',
#   'nn',
#   'nns',
#   u'noodles',
#   u'nooooo',
#   u'oh',
#   u'ohhhhh',
#   u'okay',
#   u'omg',
#   u'omgaaaaawd',
#   u'omo',
#   u'oof',
#   u'ooh',
#   u'oooh',
#   u'oppa',
#   u'outside',
#   u'park',
#   u'pay',
#   u'people',
#   u'pffft',
#   u'phew',
#   u'player',
#   u'please',
#   u'poison',
#   u'poor',
#   u'prosecutor',
#   u'public',
#   u'punk',
#   u'queen',
#   u'raoulis',
#   u'rapper',
#   u'rawr',
#   u'red',
#   u'rude',
#   u'runa',
#   u'runas',
#   u'safe',
#   u'sang-soo',
#   u'save',
#   u'scientist',
#   u'scientists',
#   u'season',
#   u'security',
#   u'see',
#   u'sharp',
#   u'shed',
#   u'shes',
#   u'shuffles',
#   u'sidekick',
#   u'sirens',
#   u'sis',
#   u'slam',
#   u'sledgehammer',
#   u'slowly',
#   u'snake',
#   u'snitch',
#   u'sora',
#   u'soras',
#   u'sorry',
#   u'special',
#   u'squeak',
#   u'squee',
#   u'ssup',
#   u'stab',
#   u'starlet',
#   u'starlets',
#   u'sun-jung',
#   u'tae-yeon',
#   u'third',
#   u'time',
#   u'tiny',
#   u'todays',
#   u'tokyo',
#   u'torture',
#   u'truck',
#   u'true',
#   u'try',
#   u'turn',
#   u'uncle',
#   u'urg',
#   u'vamp',
#   u'vampire',
#   u'wait',
#   u'water',
#   u'welcome',
#   u'were',
#   u'whaa',
#   u'whats',
#   u'where',
#   u'wheres',
#   u'which',
#   u'whoa',
#   u'whoopdedo',
#   u'whos',
#   u'will',
#   u'wolfram',
#   u'yaja',
#   u'yang',
#   u'yeon',
#   u'yeon-ji',
#   u'yoo',
#   u'yoos',
#   u'yoshitaka',
#   u'young-ae',
#   u'youre',
#   u'youve',
#   u'yu-jin',
#   u'yunno',
#   u'yup',
#   u'yuriko'},
#  {u'adobe',
#   u'aha',
#   u'ahhhhhh',
#   u'ajusshi',
#   u'alas',
#   u'alternate',
#   u'amidst',
#   u'arirang',
#   u'baek-yis',
#   u'banchon',
#   u'bang',
#   u'bang-hyun',
#   u'bitter',
#   u'bizarre',
#   u'book',
#   u'busily',
#   u'choi',
#   u'chois',
#   u'chun',
#   u'clearly',
#   u'cop',
#   u'cowardly',
#   u'crazy',
#   u'curiosity',
#   u'curiouser',
#   u'curiously',
#   u'curse',
#   u'dad',
#   u'daddy',
#   u'dae-su',
#   u'dearest',
#   u'dearests',
#   u'deeper',
#   u'doesnt',
#   u'download',
#   u'dragon',
#   u'du',
#   u'dubak',
#   u'father',
#   u'fearful',
#   u'flash',
#   u'furious',
#   u'gold',
#   u'good',
#   u'guards',
#   u'halfway',
#   u'hansel',
#   u'hanyang',
#   u'heo',
#   u'hes',
#   u'hidden',
#   u'hilariously',
#   u'horrified',
#   u'hyung-do',
#   u'id',
#   u'ill',
#   u'inside',
#   u'investigator',
#   u'ive',
#   u'jang',
#   u'jangs',
#   u'ji',
#   u'ji-hoon',
#   'jj',
#   u'joon-seok',
#   u'joseon',
#   u'kang',
#   u'kim',
#   u'king',
#   u'korea',
#   u'late',
#   u'launch',
#   u'lee',
#   u'lees',
#   u'local',
#   u'lord',
#   u'lucite',
#   u'lucky',
#   u'man',
#   u'men',
#   u'mixed',
#   u'monsters',
#   u'nearby',
#   'nn',
#   u'officer',
#   u'oh',
#   u'oops',
#   u'park',
#   u'player',
#   u'psychic',
#   u'rainwater',
#   u'saucy',
#   u'seok-beom',
#   u'seung',
#   u'seungs',
#   u'shinmuhwe',
#   u'shinmuhwes',
#   u'silla',
#   u'so',
#   u'someone',
#   u'soon',
#   u'soon-tak',
#   u'storyteller',
#   u'stranger',
#   u'suspenseful',
#   u'tattoo',
#   u'teacher',
#   u'team',
#   u'tokki',
#   u'touch',
#   u'true',
#   u'unhurt',
#   u'unperturbed',
#   u'wait',
#   u'water',
#   u'weakly',
#   u'well',
#   u'weve',
#   u'which',
#   u'will',
#   u'wow',
#   u'wryly',
#   u'x-files',
#   u'yellow',
#   u'yoon-yi',
#   u'youve',
#   u'yu-seok'},
#  {u'afterward',
#   u'again',
#   u'aha',
#   u'ahhhh',
#   u'ahn',
#   u'ahns',
#   u'airport',
#   u'andante',
#   u'aunt',
#   u'aww',
#   u'awww',
#   u'beautiful',
#   u'blood',
#   u'bosss',
#   u'butterfly',
#   u'bye',
#   u'chairwoman',
#   u'choi',
#   u'cinderella',
#   u'cool',
#   u'copy',
#   u'creator',
#   u'cue',
#   u'cut',
#   u'cuuute',
#   u'dad',
#   u'dads',
#   u'dan-tae',
#   u'dan-taes',
#   u'dan-taxi',
#   u'deal',
#   u'direct',
#   u'dna',
#   u'dont',
#   u'drunk',
#   u'duty',
#   u'everyones',
#   u'father',
#   u'flashback',
#   u'flustered',
#   u'forces',
#   u'fraud',
#   u'fun',
#   u'gandma',
#   u'ghim',
#   u'gimpo',
#   u'girl',
#   u'goddess',
#   u'gong',
#   u'gongs',
#   u'grandma',
#   u'grandmas',
#   u'grandmother',
#   u'guess',
#   u'hah',
#   u'haha',
#   u'happily',
#   u'hed',
#   u'hee',
#   u'heh',
#   u'hehe',
#   u'hell',
#   u'hence',
#   u'hes',
#   u'hit',
#   u'hyuan',
#   u'hyung',
#   u'ill',
#   u'im',
#   u'inside',
#   u'island',
#   u'jealousy',
#   u'jeju',
#   u'jin',
#   'jj',
#   u'jun-pyo',
#   u'korea',
#   u'little',
#   u'love',
#   u'lucky',
#   u'meanies',
#   u'memorial',
#   u'mhmm',
#   u'mi',
#   u'minion',
#   u'mis',
#   u'miss',
#   u'mom',
#   u'mother',
#   u'mr.',
#   u'naengmyeon',
#   u'nearby',
#   u'next',
#   'nn',
#   'nns',
#   u'ohn',
#   u'okay',
#   u'oof',
#   u'ooh',
#   u'ooof',
#   u'oooh',
#   u'oops',
#   u'original',
#   u'ouch',
#   u'outside',
#   u'park',
#   u'pshh',
#   u'pssh',
#   u'riiiight',
#   u'seok',
#   u'seoks',
#   u'sergeant',
#   u'sham',
#   u'shes',
#   u'shim',
#   u'shims',
#   u'sly',
#   u'someone',
#   u'someones',
#   u'soo-young',
#   u'soon',
#   u'special',
#   u'spidey',
#   u'star',
#   u'swoon',
#   u'tae-cheol',
#   u'taken',
#   u'talk',
#   u'tattoo',
#   u'tears',
#   u'tomorrow',
#   u'twas',
#   u'typical',
#   u'uncle',
#   u'uncles',
#   u'welp',
#   u'whaaat',
#   u'whoops',
#   u'wife',
#   u'winner',
#   u'wow',
#   u'yeesh',
#   u'yeom',
#   u'yuck'},
#  {u'adobe',
#   u'anna',
#   u'are',
#   u'aww',
#   u'basically',
#   u'bongs',
#   u'boutique',
#   u'catch',
#   u'curious',
#   u'cut',
#   u'dad',
#   u'deadliest',
#   u'download',
#   u'fashion',
#   u'flash',
#   u'food',
#   u'ga-young',
#   u'girl',
#   u'good',
#   u'haha',
#   u'han',
#   u'harsh',
#   u'hes',
#   u'im',
#   u'jang',
#   u'jin-sung',
#   'jj',
#   u'jo',
#   u'jos',
#   u'kim',
#   u'king',
#   u'lee',
#   u'love',
#   u'madam',
#   u'madame',
#   'nn',
#   'nnps',
#   'nns',
#   u'past',
#   u'player',
#   u'poor',
#   u'prada',
#   u'rain',
#   u'ratings',
#   u'rolex',
#   u'shes',
#   u'wears',
#   u'weve',
#   u'young',
#   u'yuri'},
#  {u'afterward',
#   u'agent',
#   u'ahn',
#   u'alarmed',
#   u'almost',
#   u'already',
#   u'anxious',
#   u'apathetic',
#   u'baek',
#   u'cant',
#   u'caught',
#   u'cha-kyung',
#   u'chairman',
#   u'chairwoman',
#   u'chief',
#   u'choi',
#   u'chois',
#   u'crimes',
#   u'cue',
#   u'curiously',
#   u'dae-woong',
#   u'ddakj',
#   u'ddakji',
#   u'ddakjis',
#   u'ddkajis',
#   u'detective',
#   u'director',
#   u'disturbed',
#   u'dont',
#   u'down',
#   u'due',
#   u'eun-bi',
#   u'eyes',
#   u'free',
#   u'gil-choon',
#   u'gook',
#   u'gooks',
#   u'guys',
#   u'haha',
#   u'hed',
#   u'hehe',
#   u'hes',
#   u'hey',
#   u'hidden',
#   u'ill',
#   u'im',
#   u'incheon',
#   u'inside',
#   u'jang',
#   u'jin-young',
#   'jj',
#   u'jong-sam',
#   u'jong-sams',
#   u'kang',
#   u'kangdarts',
#   u'kangs',
#   u'ki',
#   u'kihes',
#   u'kim',
#   u'kimnow',
#   u'kims',
#   u'kwak',
#   u'kwaks',
#   u'kyujng',
#   u'kyung',
#   u'kyungs',
#   u'lawyer',
#   u'lee',
#   u'leebut',
#   u'lees',
#   u'little',
#   u'luckily',
#   u'maknae',
#   u'man',
#   u'mom',
#   u'moms',
#   u'morse',
#   u'mr.',
#   u'murder',
#   u'musan',
#   u'my',
#   'nn',
#   u'off',
#   u'officer',
#   u'oh',
#   u'oppa',
#   u'outside',
#   u'park',
#   u'parks',
#   u'penitentiary',
#   u'port',
#   u'prosecutor',
#   u'roll',
#   u'shed',
#   u'someone',
#   u'soon',
#   u'suspicious',
#   u'take',
#   u'theyve',
#   u'thien',
#   u'unit',
#   u'unperturbed',
#   u'watch',
#   u'weve',
#   u'whew',
#   u'wife',
#   u'will',
#   u'yirim'},
#  {u'adult',
#   u'ahn',
#   u'alarmed',
#   u'ashamed',
#   u'aunty',
#   u'awesome',
#   u'awww',
#   u'be',
#   u'ceo',
#   u'cha',
#   u'chairman',
#   u'charmed',
#   u'cheater',
#   u'chungho',
#   u'class',
#   u'cornered',
#   u'cut',
#   u'cute',
#   u'daddy',
#   u'damn',
#   u'department',
#   u'director',
#   u'doctor',
#   u'done',
#   u'dong-seok',
#   u'dont',
#   u'driver',
#   u'eeeee',
#   u'elsa',
#   u'excited',
#   u'father',
#   u'foundation',
#   u'goodbye',
#   u'grandmother',
#   u'grouchy',
#   u'ha',
#   u'hae-chul',
#   u'hae-sung',
#   u'has',
#   u'heads',
#   u'hed',
#   u'heh',
#   u'hell',
#   u'hes',
#   u'ho-bang',
#   u'horrified',
#   u'how',
#   u'hurry',
#   u'hwang',
#   u'hwangs',
#   u'hyun',
#   u'hyuns',
#   u'ill',
#   u'inside',
#   u'ive',
#   u'jang',
#   u'jason',
#   u'jealous',
#   u'jenga',
#   u'jin-ju',
#   'jj',
#   u'jung',
#   u'kang',
#   u'kim',
#   u'kyung-chul',
#   u'lee',
#   u'lees',
#   u'listen',
#   u'luckily',
#   u'midnight',
#   u'miss',
#   u'mr.',
#   u'mystery',
#   u'mysterys',
#   u'nearby',
#   'nn',
#   'nnps',
#   u'okay',
#   u'one',
#   u'oof',
#   u'oops',
#   u'oppa',
#   u'outside',
#   u'paranoid',
#   u'park',
#   u'pasta',
#   u'pastas',
#   u'poor',
#   u'potter',
#   u'pretty',
#   u'runner',
#   u'sang-hyun',
#   u'shes',
#   u'shocked',
#   u'sohn',
#   u'sohns',
#   u'store',
#   u'stores',
#   u'stricken',
#   u'take',
#   u'teacher',
#   u'tomorrow',
#   u'too',
#   u'touched',
#   u'unaware',
#   u'uncle',
#   u'uncuff',
#   u'wait',
#   u'which',
#   u'whoa',
#   u'woo',
#   u'worlds',
#   u'worried',
#   u'wow',
#   u'yang',
#   u'yoo-min',
#   u'youll',
#   u'youre'},
#  {u'adobe',
#   u'afraid',
#   u'again',
#   u'ahhh',
#   u'ahjusshi',
#   u'ajumma',
#   u'ajusshi',
#   u'alarmed',
#   u'alas',
#   u'alright',
#   u'angelina',
#   u'annual',
#   u'anyway',
#   u'aproof',
#   u'autumn',
#   u'awesomesauce',
#   u'aww',
#   u'baby',
#   u'baek',
#   u'barely',
#   u'barley',
#   u'beautiful',
#   u'beta',
#   u'bibimbap',
#   u'brazil',
#   u'breakfast',
#   u'breeze',
#   u'buddy',
#   u'buzz',
#   u'car',
#   u'care',
#   u'center',
#   u'chauffeur',
#   u'choi',
#   u'christmas',
#   u'chu',
#   u'chun',
#   u'chun-hee',
#   u'chun-hees',
#   u'chunderella',
#   u'coffee',
#   u'colin',
#   u'coward',
#   u'creepella',
#   u'cupids',
#   u'cute',
#   u'daddy',
#   u'deville',
#   u'director',
#   u'doesnt',
#   u'dong-chan',
#   u'dont',
#   u'download',
#   u'downstairs',
#   u'eve',
#   u'evil',
#   u'exactly',
#   u'exhibit',
#   u'family',
#   u'father',
#   u'fine',
#   u'firth',
#   u'flash',
#   u'footsteps',
#   u'fortuna',
#   u'fresh',
#   u'gear',
#   u'geez',
#   u'generation',
#   u'geum',
#   u'geum-ja',
#   u'girls',
#   u'global',
#   u'globals',
#   u'go',
#   u'gon',
#   u'goodbye',
#   u'goodnight',
#   u'got',
#   u'gramps',
#   u'granda',
#   u'grandfather',
#   u'grandpa',
#   u'grandpas',
#   u'grant',
#   u'granted',
#   u'gu',
#   u'haha',
#   u'hahaha',
#   u'han',
#   u'han-sae',
#   u'han-se',
#   u'hands',
#   u'hang',
#   u'happy',
#   u'heads',
#   u'hed',
#   u'hee',
#   u'hees',
#   u'hehe',
#   u'hehehe',
#   u'hello',
#   u'her',
#   u'hes',
#   u'hey',
#   u'heyhang',
#   u'hilarious',
#   u'hilariously',
#   u'hit',
#   u'ho',
#   u'ho-jin',
#   u'hold',
#   u'honey',
#   u'hotel',
#   u'how',
#   u'hugh',
#   u'huh',
#   u'hurray',
#   u'hurry',
#   u'hwan',
#   u'hye',
#   u'hye-jin',
#   u'hye-sun',
#   u'hyun',
#   u'hyun-soo',
#   u'hyung',
#   u'id',
#   u'idiot',
#   u'ill',
#   u'im',
#   u'imagine',
#   u'initially',
#   u'inside',
#   u'invariably',
#   u'ive',
#   u'ji',
#   u'ji-hoo',
#   u'jilted',
#   u'jin',
#   'jj',
#   u'jolie',
#   u'jones',
#   u'joness',
#   u'joon-bae',
#   u'juliet',
#   u'jun',
#   u'jung',
#   u'jung-in',
#   u'jung-kil',
#   u'jung-kyung',
#   u'jung-yoon',
#   u'kang',
#   u'karaoke',
#   u'kim',
#   u'kims',
#   u'koala',
#   u'korea',
#   u'koreas',
#   u'kyu',
#   u'kyu-han',
#   u'kyung',
#   u'kyung-ho',
#   u'kyungs',
#   u'leader',
#   u'lee',
#   u'look',
#   u'love',
#   u'lucky',
#   u'maam',
#   u'macho',
#   u'mama',
#   u'man-bok',
#   u'married',
#   u'marry',
#   u'maybe',
#   u'melo',
#   u'mi',
#   u'min',
#   u'min-joon',
#   u'min-jung',
#   u'miss',
#   u'mom',
#   u'moon',
#   u'mother',
#   u'motors',
#   u'mr.',
#   u'mung',
#   u'my',
#   u'mystery',
#   u'myung',
#   'nn',
#   u'norah',
#   u'nose',
#   u'o',
#   u'ok-sook',
#   u'okay',
#   u'oooh',
#   u'oppa',
#   u'outing',
#   u'outside',
#   u'overload',
#   u'paradise',
#   u'player',
#   u'please',
#   u'poison',
#   u'poor',
#   u'pretty',
#   u'prince',
#   u'puhaha',
#   u'puhahaha',
#   u'que',
#   u'quit',
#   u'really',
#   u'right',
#   u'romeo',
#   u'runny',
#   u'sam',
#   u'sang-hoon',
#   u'seduce',
#   u'see',
#   u'seo',
#   u'seok-woo',
#   u'seos',
#   u'sera',
#   u'sexy',
#   u'shed',
#   u'shes',
#   u'shin',
#   u'shut',
#   u'si',
#   u'smile',
#   u'snow',
#   u'so',
#   u'sonata',
#   u'song',
#   u'soon',
#   u'soos',
#   u'sorry',
#   u'soyjoy',
#   u'stick',
#   u'suk-woo',
#   u'sun',
#   u'sunwoo',
#   u'syndrome',
#   u'system',
#   u'tae',
#   u'taken',
#   u'team',
#   u'technically',
#   u'tiger',
#   u'too',
#   u'top',
#   u'toyota',
#   u'tuck',
#   u'unni',
#   u'vacation',
#   u'wait',
#   u'watch',
#   u'well',
#   u'were',
#   u'weve',
#   u'whether',
#   u'which',
#   u'white',
#   u'wholl',
#   u'whyare',
#   u'wink',
#   u'winter',
#   u'woman',
#   u'woods',
#   u'words',
#   u'wow',
#   u'yang',
#   u'years',
#   u'yeouch',
#   u'yoon',
#   u'youd',
#   u'youngs',
#   u'youre',
#   u'youve',
#   u'yurisangja'},
#  {u'adobe',
#   u'afterward',
#   u'alarmed',
#   u'answer',
#   u'anxious',
#   u'architecture',
#   u'aware',
#   u'bleakly',
#   u'blue',
#   u'bu-san',
#   u'bumseo',
#   u'bumseos',
#   u'cars',
#   u'cha',
#   u'cheerfully',
#   u'christmas',
#   u'chun',
#   u'chun-hee',
#   u'chun-hees',
#   u'chuno',
#   u'city',
#   u'coward',
#   u'cry',
#   u'cut',
#   u'daddy',
#   u'did',
#   u'dinner',
#   u'disappear',
#   u'disturbed',
#   u'doesnt',
#   u'dont',
#   u'download',
#   u'drang',
#   u'drunk',
#   u'dully',
#   u'dummy',
#   u'fade',
#   u'fall',
#   u'father',
#   u'fear',
#   u'fine',
#   u'flash',
#   u'fools',
#   u'get',
#   u'go',
#   u'god',
#   u'good',
#   u'goodbye',
#   u'gossip',
#   u'green',
#   u'group',
#   u'groups',
#   u'guiltily',
#   u'gummy',
#   u'han',
#   u'harshly',
#   u'heaven',
#   u'hed',
#   u'hell',
#   u'hero',
#   u'hes',
#   u'hit',
#   u'ho-jin',
#   u'horrified',
#   u'hours',
#   u'house',
#   u'huh',
#   u'hyung',
#   u'id',
#   u'idiot',
#   u'idiots',
#   u'ill',
#   u'im',
#   u'inside',
#   u'isnt',
#   u'ive',
#   u'ji-wan',
#   u'ji-wan.yes',
#   u'ji-yong',
#   'jj',
#   u'jung-pil',
#   u'just',
#   u'kang-jin',
#   u'kim',
#   u'kims',
#   u'leader',
#   u'lee',
#   u'les',
#   u'lets',
#   u'liar',
#   u'life',
#   u'little',
#   u'love',
#   u'lucid',
#   u'lucite',
#   u'madam',
#   u'magically',
#   u'mama',
#   u'man',
#   u'miserables',
#   u'miss',
#   u'mom',
#   u'moms',
#   u'mother',
#   u'move',
#   u'national',
#   'nn',
#   'nns',
#   u'oops',
#   u'oppa',
#   u'ost',
#   u'otherwise',
#   u'park',
#   u'pastel',
#   u'player',
#   u'point',
#   u'quickly',
#   u'rainy',
#   u'rather',
#   u'sarang',
#   u'seo',
#   u'seoul',
#   u'shes',
#   u'shim',
#   u'shin',
#   u'shut',
#   u'snow',
#   u'someone',
#   u'soo',
#   u'soon',
#   u'sorry',
#   u'stay',
#   u'su-bongs',
#   u'tae-joon',
#   u'take',
#   u'team',
#   u'tears',
#   u'test',
#   u'tokki',
#   u'tonight',
#   u'touch',
#   u'true',
#   u'university',
#   u'weak',
#   u'well',
#   u'were',
#   u'which',
#   u'white',
#   u'will',
#   u'winter',
#   u'woo-jung',
#   u'wordlessly',
#   u'wow',
#   u'ye-seul',
#   u'yeah',
#   u'yeon-woo',
#   u'youre',
#   u'youve'},
#  {u'ajusshi',
#   u'bae',
#   u'boss',
#   u'geum-bi',
#   u'happy',
#   'jj',
#   u'joseon',
#   u'my',
#   u'oh',
#   u'outside'},
#  {u'adult',
#   u'again',
#   u'aha',
#   u'ahn',
#   u'ajumma',
#   u'ajusshi',
#   u'ajusshis',
#   u'aloud',
#   u'annnnd',
#   u'annnnnd',
#   u'armed',
#   u'arrows',
#   u'astonished',
#   u'audrey',
#   u'awkward',
#   u'aww',
#   u'awww',
#   u'bang',
#   u'be',
#   u'bewildered',
#   u'billion',
#   u'born',
#   u'brow',
#   u'bruce',
#   u'cha',
#   u'chairman',
#   u'challenge',
#   u'chi-hyun',
#   u'child',
#   u'christmas',
#   u'chun',
#   u'chung',
#   u'chungie',
#   u'chungs',
#   u'cinderella',
#   u'city',
#   u'crap',
#   u'crazy',
#   u'cut',
#   u'dad',
#   u'dads',
#   u'dae-young',
#   u'dam-ryung',
#   u'dammit',
#   u'dayum',
#   u'detective',
#   u'die',
#   u'disney',
#   u'doctor',
#   u'dong-won',
#   u'dont',
#   u'dork',
#   u'downstairs',
#   u'drunk',
#   u'dubai',
#   u'elizabeth',
#   u'enraged',
#   u'enter',
#   u'entranced',
#   u'epilogue',
#   u'ergo',
#   u'faaaaaar',
#   u'far',
#   u'fashionista',
#   u'father',
#   u'flattered',
#   u'gah',
#   u'gangnam',
#   u'gangnams',
#   u'get',
#   u'girl',
#   u'gong',
#   u'gossip',
#   u'gun',
#   u'gyecheon',
#   u'hacker',
#   u'hae-jin',
#   u'haha',
#   u'hahaha',
#   u'hahahaha',
#   u'hawaii',
#   u'hed',
#   u'heh',
#   u'hehe',
#   u'hello',
#   u'help',
#   u'heo',
#   u'heos',
#   u'hercules',
#   u'hes',
#   u'hit',
#   u'homeless',
#   u'honest',
#   u'hong',
#   u'hongs',
#   u'housekeeper',
#   u'hul',
#   u'hurry',
#   u'hyo-jin',
#   u'hyung',
#   u'ill',
#   u'im',
#   u'inhyun',
#   u'inside',
#   u'ive',
#   u'jang',
#   u'jeon',
#   u'ji-hyun',
#   u'jin',
#   'jj',
#   u'jjimjilbang',
#   u'jo',
#   u'joon-jae',
#   u'joseon',
#   u'jung',
#   u'just',
#   u'kang',
#   u'karma',
#   u'killer',
#   u'kim',
#   u'know',
#   u'kyaaa',
#   u'lee',
#   u'legend',
#   u'lets',
#   u'little',
#   u'lol',
#   u'lord',
#   u'ma',
#   u'man',
#   u'manager',
#   u'me',
#   u'mermaid',
#   u'miffed',
#   u'mimi',
#   u'mines',
#   u'mom',
#   u'momkeeper',
#   u'moms',
#   u'moon',
#   u'mr.',
#   u'muahaha',
#   u'my',
#   u'nam',
#   u'nam-doo',
#   u'nams',
#   u'namsan',
#   u'next',
#   'nn',
#   'nns',
#   u'noooooo',
#   u'normally',
#   u'oh',
#   u'ohhh',
#   u'okay',
#   u'omg',
#   u'ooh',
#   u'park',
#   u'past',
#   u'pastor',
#   u'person',
#   u'pert',
#   u'pffft',
#   u'pfft',
#   u'please',
#   u'professor',
#   u'pwahaha',
#   u'queen',
#   u'ramyun',
#   u'rawr',
#   u'rich',
#   u'right',
#   u'river',
#   u'romeo',
#   u'same',
#   u'santa',
#   u'sassy',
#   u'satisfied',
#   u'scared',
#   u'se-hwa',
#   u'see',
#   u'seoul',
#   u'shed',
#   u'shes',
#   u'shi-ah',
#   u'shim',
#   u'six',
#   u'slowly',
#   u'snow',
#   u'snowflakes',
#   u'soon',
#   u'sorry',
#   u'stepmom',
#   u'stepmoms',
#   u'stepom',
#   u'stepson',
#   u'stick',
#   u'strangeri',
#   u'stung',
#   u'swoon',
#   u'tae-hyun',
#   u'tears',
#   u'teenage',
#   u'thats',
#   u'thomas',
#   u'thump',
#   u'todays',
#   u'tonight',
#   u'tower',
#   u'unni',
#   u'waaaaah',
#   u'wait',
#   u'well',
#   u'where',
#   u'which',
#   u'who',
#   u'will',
#   u'wow',
#   u'yang',
#   u'yangs',
#   u'yoon',
#   u'yoons',
#   u'younger',
#   u'youre',
#   u'youve',
#   u'yumi'},
#  {u'aaaaargh',
#   u'abandoned',
#   u'adobe',
#   u'adult',
#   u'again',
#   u'ahhh',
#   u'ajusshi',
#   u'alan',
#   u'alarmed',
#   u'alas',
#   u'almost',
#   u'angel',
#   u'anyone',
#   u'anyway',
#   u'apple',
#   u'ask',
#   u'awesome',
#   u'awkward',
#   u'aww',
#   u'bad',
#   u'bait',
#   u'bastard',
#   u'batshit',
#   u'been',
#   u'big',
#   u'bingo',
#   u'blood',
#   u'brava',
#   u'bravo',
#   u'break',
#   u'breaks',
#   u'bro',
#   u'bros',
#   u'brother',
#   u'buh',
#   u'buzzkill',
#   u'care',
#   u'choi',
#   u'chop',
#   u'christmas',
#   u'chungsoo',
#   u'city',
#   u'claus',
#   u'coffee',
#   u'coincidence',
#   u'collide',
#   u'coma',
#   u'constructions',
#   u'cop',
#   u'cops',
#   u'crap',
#   u'curious',
#   u'cute',
#   u'dad',
#   u'daddy',
#   u'damn',
#   u'dancing',
#   u'deaf',
#   u'dear',
#   u'dearest',
#   u'deus',
#   u'didnt',
#   u'director',
#   u'dirty',
#   u'does',
#   u'dont',
#   u'down',
#   u'download',
#   u'driver',
#   u'dude',
#   u'duly',
#   u'eeeeeek',
#   u'eldest',
#   u'engineer',
#   u'eom',
#   u'eoms',
#   u'evil',
#   u'eye',
#   u'fa',
#   u'father',
#   u'finally',
#   u'find',
#   u'fine',
#   u'flash',
#   u'funny',
#   u'gah',
#   u'geez',
#   u'girl',
#   u'goddamn',
#   u'greenbergs',
#   u'group',
#   u'groups',
#   u'guarantor',
#   u'gun-wook',
#   u'guy',
#   u'ha',
#   u'haeshin',
#   u'haeshinit',
#   u'haeshins',
#   u'hagwitch',
#   u'haha',
#   u'hahaha',
#   u'han',
#   u'happy',
#   u'heavens',
#   u'hed',
#   u'heh',
#   u'hell',
#   u'hello',
#   u'hes',
#   u'hey',
#   u'high',
#   u'hilarious',
#   u'hilariously',
#   u'honey',
#   u'hong',
#   u'hongs',
#   u'how',
#   u'husband',
#   u'husbands',
#   u'hye-joo',
#   u'hyo-joo',
#   u'hyung',
#   u'id',
#   u'idiots',
#   u'ill',
#   u'illegal',
#   u'im',
#   u'inside',
#   u'island',
#   u'ive',
#   u'jackpot',
#   u'jae-in',
#   u'jae-wook',
#   u'jaejoongs',
#   u'jang',
#   u'jangs',
#   u'jeju',
#   u'jerry',
#   'jj',
#   u'john',
#   u'joo-hee',
#   u'jung',
#   u'kah',
#   u'kang',
#   u'kangs',
#   u'kim',
#   u'kims',
#   u'kudos',
#   u'lady',
#   u'less',
#   u'listen',
#   u'little',
#   u'luckily',
#   u'lucky',
#   u'macbeths',
#   u'madam',
#   u'master',
#   u'mightily',
#   u'mister',
#   u'mme',
#   u'mo-nae',
#   u'mom',
#   u'mommie',
#   u'mommy',
#   u'moms',
#   u'moon',
#   u'mother',
#   u'mr.',
#   u'nam-gil',
#   u'napoleon',
#   'nn',
#   u'noble',
#   u'noise',
#   u'noona',
#   u'okay',
#   u'old',
#   u'ooh',
#   u'oops',
#   u'oppa',
#   u'outside',
#   u'paid',
#   u'paths',
#   u'personal',
#   u'player',
#   u'please',
#   u'plottery',
#   u'polaroid',
#   u'poof',
#   u'poor',
#   u'postman',
#   u'potayto',
#   u'princes',
#   u'queer',
#   u'quickly',
#   u'radar',
#   u'rawr',
#   u'rich',
#   u'right',
#   u'romeo',
#   u'rope',
#   u'ryu',
#   u'ryus',
#   u'santa',
#   u'say',
#   u'seduce',
#   u'selfridges',
#   u'seo',
#   u'seoul',
#   u'sexy',
#   u'shed',
#   u'shes',
#   u'shim',
#   u'shin',
#   u'shins',
#   u'show',
#   u'shut',
#   u'sigh',
#   u'sister',
#   u'sisters',
#   u'smart',
#   u'someone',
#   u'son',
#   u'sons',
#   u'sorry',
#   u'spoken',
#   u'springer',
#   u'sun-young',
#   u'super',
#   u'suspect',
#   u'suspicious',
#   u't',
#   u'tae-sung',
#   u'taken',
#   u'taste',
#   u'tears',
#   u'thats',
#   u'thrown',
#   u'touch',
#   u'unperturbed',
#   u'vanila',
#   u'vengeance',
#   u'wait',
#   u'well',
#   u'weve',
#   u'wha',
#   u'whats',
#   u'which',
#   u'whoa',
#   u'wow',
#   u'yeo-hee',
#   u'yeob',
#   u'yoon',
#   u'yoon-chul',
#   u'young',
#   u'youre',
#   u'youtube',
#   u'youve'},
#  {u'adobe',
#   u'again',
#   u'alright',
#   u'anger',
#   u'annoyed',
#   u'anyone',
#   u'awesome',
#   u'awkward',
#   u'aww',
#   u'awwwww',
#   u'baby',
#   u'bae',
#   u'baek',
#   u'baes',
#   u'beaten',
#   u'bok',
#   u'boss',
#   u'boy',
#   u'bridge',
#   u'bu',
#   u'busan',
#   u'chairman',
#   u'chauffeur',
#   u'choi',
#   u'christian',
#   u'christmas',
#   u'chul',
#   u'chuls',
#   u'cinderella',
#   u'civil',
#   u'click',
#   u'coffee',
#   u'copperfield',
#   u'cpr',
#   u'dad',
#   u'daddy',
#   u'dads',
#   u'dae',
#   u'daes',
#   u'dang',
#   u'david',
#   u'did',
#   u'dna',
#   u'do',
#   u'doctor',
#   u'doesnt',
#   u'dong',
#   u'dont',
#   u'dos',
#   u'dramas',
#   u'dude',
#   u'duk',
#   u'dun',
#   u'everyone',
#   u'everyones',
#   u'evil',
#   u'excited',
#   u'fair',
#   u'family',
#   u'farewell',
#   u'father',
#   u'faux',
#   u'feel',
#   u'fishery',
#   u'flash',
#   u'ga',
#   u'gah',
#   u'gangnam',
#   u'girl',
#   u'go',
#   u'gop',
#   u'gosh',
#   u'gotcha',
#   u'granny',
#   u'gu',
#   u'guess',
#   u'guhas',
#   u'gus',
#   u'gwangan',
#   u'gwanghan',
#   u'gyu',
#   u'ha',
#   u'hae',
#   u'haeundae',
#   u'haha',
#   u'hahah',
#   u'hahaha',
#   u'half',
#   u'happy',
#   u'harsh',
#   u'hee',
#   u'hees',
#   u'heh',
#   u'hell',
#   u'hello',
#   u'hellos',
#   u'hes',
#   u'hmm',
#   u'ho',
#   u'hos',
#   u'hotel',
#   u'hotels',
#   u'how',
#   u'hunter',
#   u'hyuk',
#   u'hyukisnttrying',
#   u'hyuks',
#   u'ill',
#   u'im',
#   u'incest',
#   u'investigator',
#   u'isnt',
#   u'ive',
#   u'ja',
#   'jj',
#   u'jo',
#   u'joo',
#   u'joon',
#   u'joong',
#   u'joons',
#   u'jos',
#   u'jung',
#   u'kaedejun',
#   u'kang',
#   u'kang-woo',
#   u'kim',
#   u'kitty',
#   u'kittys',
#   u'kudos',
#   u'kwan',
#   u'kyung',
#   u'lady',
#   u'lee',
#   u'lees',
#   u'likewise',
#   u'lock',
#   u'looks',
#   u'lovers',
#   u'mal',
#   u'mama',
#   u'man',
#   u'master',
#   u'medics',
#   u'meeeee',
#   u'min',
#   u'mohawk',
#   u'mom',
#   u'mother',
#   u'mr.',
#   u'na',
#   u'nabefore',
#   u'nam',
#   u'nas',
#   u'never',
#   'nn',
#   'nnps',
#   'nns',
#   u'nope',
#   u'nyeon',
#   u'oh',
#   u'okay',
#   u'ooh',
#   u'oooh',
#   u'oppa',
#   u'ouch',
#   u'park',
#   u'pfff',
#   u'pffttt',
#   u'player',
#   u'point',
#   u'poo',
#   u'poor',
#   u'prestige',
#   u'problem',
#   u'problems',
#   u'psy',
#   u'psys',
#   u'pyong',
#   u'rather',
#   u'ri',
#   u'romeo',
#   u'rumor',
#   u'sae',
#   u'satisfied',
#   u'score',
#   u'se',
#   u'see',
#   u'seok',
#   u'shes',
#   u'shik',
#   u'shiks',
#   u'shim',
#   u'shin',
#   u'shocked',
#   u'shower',
#   u'simply',
#   u'smart',
#   u'so',
#   u'somehow',
#   u'someone',
#   u'son',
#   u'sonata',
#   u'sons',
#   u'sook',
#   u'soon',
#   u'soons',
#   u'sora',
#   u'soranow',
#   u'soras',
#   u'sorry',
#   u'sourpuss',
#   u'speaks',
#   u'stomach',
#   u'stupid',
#   u'style',
#   u'sung',
#   u'sungisthe',
#   u'sungreally',
#   u'sungs',
#   u'sungso',
#   u'tada',
#   u'tae',
#   u'tam',
#   u'thank',
#   u'thanks',
#   u'trust',
#   u'uncle',
#   u'uncles',
#   u'upset',
#   u'vice',
#   u'wait',
#   u'well',
#   u'whats',
#   u'whew',
#   u'which',
#   u'whichthen',
#   u'whoa',
#   u'whooosh',
#   u'whos',
#   u'whut',
#   u'won',
#   u'woo',
#   u'wow',
#   u'wrong',
#   u'yang',
#   u'yangs',
#   u'yeah',
#   u'yeo',
#   u'yep',
#   u'yong',
#   u'yook',
#   u'yoon',
#   u'young',
#   u'yummy'},
#  {u'aji-3',
#   u'ajusshi',
#   u'ask',
#   u'aww',
#   u'awww',
#   u'baek-gyun',
#   u'baton',
#   u'birthday',
#   u'blotches',
#   u'blue',
#   u'boy',
#   u'brains',
#   u'butler',
#   u'chae',
#   u'chairman',
#   u'curly',
#   u'dad',
#   u'daeyang',
#   u'daeyangs',
#   u'director',
#   u'dont',
#   u'doo-sang',
#   u'dooooo',
#   u'eager',
#   u'elsewhere',
#   u'enter',
#   u'eom',
#   u'everyones',
#   u'face',
#   u'flustered',
#   u'friend',
#   u'fungus',
#   u'galileo',
#   u'geumho',
#   u'goodbye',
#   u'guy',
#   u'haha',
#   u'hahaha',
#   u'happy',
#   u'hed',
#   u'help',
#   u'hes',
#   u'hilariously',
#   u'horrible',
#   u'hungry',
#   u'hurt',
#   u'hwang',
#   u'ill',
#   u'im',
#   u'input',
#   u'inside',
#   u'jang',
#   u'jerk',
#   u'jia',
#   u'jias',
#   'jj',
#   u'jo',
#   u'kang',
#   u'kim',
#   u'kiss',
#   u'left',
#   u'lets',
#   u'lol',
#   u'madame',
#   u'man',
#   u'manager',
#   u'maria',
#   u'marias',
#   u'mast',
#   u'master',
#   u'min-kyu',
#   u'mode',
#   u'nasty',
#   'nn',
#   'nns',
#   u'ohhh',
#   u'okay',
#   u'operation',
#   u'outside',
#   u'park',
#   u'part',
#   u'pi',
#   u'poor',
#   u'pretty',
#   u'prettys',
#   u'research',
#   u'ri-el',
#   u'riel',
#   u'robovac',
#   u'room',
#   u'santa',
#   u'seung-ho',
#   u'shed',
#   u'shes',
#   u'shipbuilding',
#   u'shipbuildings',
#   u'skinship',
#   u'snow',
#   u'someone',
#   u'soo-bin',
#   u'sparks',
#   u'stay',
#   u'steel',
#   u'success',
#   u'summer',
#   u'sun-hye',
#   u'sung',
#   u'sungs',
#   u'team',
#   u'teams',
#   u'terrified',
#   u'three',
#   u'touch',
#   u'treat',
#   u'via',
#   u'whether',
#   u'who',
#   u'will',
#   u'workshop',
#   u'x',
#   u'x.',
#   u'xs',
#   u'yeh',
#   u'yoo',
#   u'yoon'},
#  {u'adobe',
#   u'afraid',
#   u'afterward',
#   u'air',
#   u'alone',
#   u'amusement',
#   u'angered',
#   u'anyway',
#   u'apgujeong',
#   u'audio',
#   u'b',
#   u'baby',
#   u'bad',
#   u'bi',
#   u'bitchy',
#   u'biuret',
#   u'bonita',
#   u'brace',
#   u'brown',
#   u'caught',
#   u'chan',
#   u'chans',
#   u'city',
#   u'couple',
#   u'crab',
#   u'dal',
#   u'dam',
#   u'dang',
#   u'dol',
#   u'dong',
#   u'doo',
#   u'doos',
#   u'drang',
#   u'execution',
#   u'eyes',
#   u'flash',
#   u'gi',
#   u'gu',
#   u'gun',
#   u'guns',
#   u'gus',
#   u'ha',
#   u'han',
#   u'hana',
#   u'hed',
#   u'hehe',
#   u'hell',
#   u'hes',
#   u'hey',
#   u'id',
#   u'ill',
#   u'im',
#   u'inside',
#   u'is',
#   u'ive',
#   u'ja',
#   u'jadu',
#   u'jae',
#   u'jas',
#   u'jiyoon',
#   'jj',
#   u'joon',
#   u'ju',
#   u'jung',
#   u'kim',
#   u'kyung',
#   u'la',
#   u'lee',
#   u'lemon',
#   u'lord',
#   u'love',
#   u'lucky',
#   u'min',
#   u'minwoo',
#   u'minwoos',
#   u'mom',
#   u'monkey',
#   u'my',
#   u'name',
#   'nn',
#   'nns',
#   u'noche',
#   u'normally',
#   u'outside',
#   u'park',
#   u'plan',
#   u'player',
#   u'please',
#   u'rain',
#   u'rainy',
#   u'ryu',
#   u'sae',
#   u'sam',
#   u'seok',
#   u'seoks',
#   u'shes',
#   u'smoke',
#   u'son',
#   u'soo',
#   u'sook',
#   u'sooks',
#   u'soon',
#   u'soons',
#   u'soos',
#   u'spring',
#   u'start',
#   u'stuck',
#   u'thus',
#   u'tree',
#   u'uptight',
#   u'village',
#   u'wait',
#   u'wan',
#   u'wans',
#   u'witch',
#   u'woman',
#   u'yeon',
#   u'yeons',
#   u'yong',
#   u'yoo',
#   u'yoon',
#   u'youd',
#   u'young',
#   u'youngs',
#   u'youre',
#   u'youve'},
#  {u'adobe',
#   u'average',
#   u'bbq',
#   u'botong',
#   u'chairman',
#   u'dokko',
#   u'dong-won',
#   u'dont',
#   u'flash',
#   u'galbi',
#   u'han',
#   u'hes',
#   u'jang',
#   u'jong-kook',
#   u'kang',
#   u'kim',
#   u'mattei',
#   u'matteis',
#   u'mine',
#   u'mom',
#   u'moms',
#   'nn',
#   u'oof',
#   u'oppa',
#   u'player',
#   u'ribs',
#   u'well',
#   u'wife'},
#  {u'afraid',
#   u'afterward',
#   u'again',
#   u'ahahaha',
#   u'annoyed',
#   u'aww',
#   u'awww',
#   u'awwww',
#   u'baek',
#   u'baeks',
#   u'barely',
#   u'bear',
#   u'blind',
#   u'bold',
#   u'breakfast',
#   u'carpe',
#   u'celine',
#   u'charles',
#   u'cheon',
#   u'chicago',
#   u'choi',
#   u'creepy',
#   u'curious',
#   u'cut',
#   u'cute',
#   u'damn',
#   u'daww',
#   u'diem',
#   u'dions',
#   u'diva',
#   u'dont',
#   u'down',
#   u'elsewhere',
#   u'eugene',
#   u'everyone',
#   u'fear',
#   u'footsteps',
#   u'game',
#   u'ghost',
#   u'golden',
#   u'gyeongbuk',
#   u'h.',
#   u'hahaha',
#   u'han',
#   u'hed',
#   u'hee',
#   u'hee-jae',
#   u'heeeeeee',
#   u'heo',
#   u'hes',
#   u'hey',
#   u'how',
#   u'hurry',
#   u'hurt',
#   u'hwi-young',
#   u'id',
#   u'ill',
#   u'im',
#   u'inside',
#   u'ive',
#   u'jeon',
#   u'jin-hyuk',
#   u'jin-oh',
#   'jj',
#   u'joseon',
#   u'joseons',
#   u'jung',
#   u'kang',
#   u'kang-joon',
#   u'keyser',
#   u'king',
#   u'kitty',
#   u'kyungsung',
#   u'liberation',
#   u'little',
#   u'lol',
#   u'lololol',
#   u'madam',
#   u'martin',
#   u'misery',
#   u'mom',
#   u'moms',
#   u'my',
#   'nn',
#   u'omo',
#   u'once',
#   u'oneill',
#   u'palace',
#   u'park',
#   u'past',
#   u'patrick',
#   u'per',
#   u'pffft',
#   u'pfft',
#   u'poor',
#   u'publishing',
#   u'reporter',
#   u'riccardo',
#   u'ryu',
#   u'sang-jin',
#   u'sang-mi',
#   u'sapsaree',
#   u'satisfied',
#   u'se-joo',
#   u'se-joos',
#   u'see',
#   u'seo',
#   u'seol',
#   u'seols',
#   u'seoul',
#   u'shes',
#   u'shin',
#   u'smart',
#   u'song',
#   u'soo-hyun',
#   u'soo-yeon',
#   u'sophia',
#   u'sophias',
#   u'sorry',
#   u'spurgeon',
#   u'spurgeons',
#   u'station',
#   u'stephen',
#   u'steve',
#   u'sun',
#   u'swayzes',
#   u'sze',
#   u'tae-min',
#   u'taken',
#   u'tears',
#   u'traitor',
#   u'typewriter',
#   u'unfair',
#   u'wait',
#   u'were',
#   u'whos',
#   u'will',
#   u'writer',
#   u'yoo',
#   u'young',
#   u'youre',
#   u'youve',
#   u'yul',
#   u'yuls'},
#  {u'adobe',
#   u'b',
#   u'beautiful',
#   u'birth',
#   u'change',
#   u'dont',
#   u'flash',
#   u'geum-ran',
#   u'grandma',
#   u'han',
#   u'hes',
#   u'ji-hye',
#   u'joo',
#   u'jung',
#   u'marry',
#   'nn',
#   u'past',
#   u'plan',
#   u'player',
#   u'sa',
#   u'sorrow',
#   u'success',
#   u'wang',
#   u'ye-seul',
#   u'youre'},
#  {u'adobe',
#   u'adult',
#   u'afterward',
#   u'airport',
#   u'awards',
#   u'awkward',
#   u'aww',
#   u'awww',
#   u'awwww',
#   u'barf',
#   u'between',
#   u'bullshit',
#   u'cartoon',
#   u'cha',
#   u'chas',
#   u'chubbo',
#   u'close',
#   u'cute',
#   u'da-bin',
#   u'dad',
#   u'daddys',
#   u'dads',
#   u'dammit',
#   u'damn',
#   u'dance',
#   u'dearest',
#   u'director',
#   u'distraught',
#   u'download',
#   u'downstairs',
#   u'drama',
#   u'editor',
#   u'effect',
#   u'elevator',
#   u'flash',
#   u'flashback',
#   u'footage',
#   u'girl',
#   u'goodbye',
#   u'group',
#   u'ha-ri',
#   u'hahahaha',
#   u'haris',
#   u'head',
#   u'hed',
#   u'hee',
#   u'heh',
#   u'hes',
#   u'home',
#   u'hooray',
#   u'hwang',
#   u'hye-jin',
#   u'hyejin',
#   u'hyung-shik',
#   u'ill',
#   u'im',
#   u'in-gook',
#   u'incheon',
#   u'island',
#   u'ive',
#   u'jackson',
#   u'james',
#   u'jeju',
#   u'ji',
#   u'jin',
#   'jj',
#   u'jung',
#   u'kim',
#   u'koreas',
#   u'lee',
#   u'left',
#   u'leonard',
#   u'lets',
#   u'love',
#   u'luckily',
#   u'makes',
#   u'me',
#   u'michael',
#   u'min',
#   u'mom',
#   u'mommy',
#   u'moms',
#   u'most',
#   u'motorcycle',
#   u'mr.',
#   u'my',
#   'nn',
#   u'nobody',
#   u'number',
#   u'oblivious',
#   u'okay',
#   u'one',
#   u'onion',
#   u'oof',
#   u'ouch',
#   u'panty',
#   u'park',
#   u'pfft',
#   u'player',
#   u'poor',
#   u'pretty',
#   u'renoir',
#   u'reporter',
#   u'rewind',
#   u'seo',
#   u'seoul',
#   u'seul',
#   u'seuls',
#   u'shed',
#   u'sheesh',
#   u'shes',
#   u'snubbed',
#   u'somehow',
#   u'soon',
#   u'stepmom',
#   u'stepmoms',
#   u'success',
#   u'sung',
#   u'sung-joon',
#   u'sung-oh',
#   u'sweet',
#   u'taylor',
#   u'ten',
#   u'tens',
#   u'touch',
#   u'touche',
#   u'umbrella',
#   u'wait',
#   u'welcome',
#   u'whoa',
#   u'whoopsie',
#   u'writer',
#   u'zeigarnik'},
#  {u'actress',
#   u'africa',
#   u'afterward',
#   u'agent',
#   u'ah-in',
#   u'ahn',
#   u'andrei',
#   u'annoyed',
#   u'awwwwww',
#   u'beyond',
#   u'black',
#   u'bong-hyun',
#   u'boobies',
#   u'boom',
#   u'boost',
#   u'boosts',
#   u'boys',
#   u'brando',
#   u'brokeback',
#   u'ceo',
#   u'cha',
#   u'champions',
#   u'choon-bong',
#   u'clara',
#   u'cue',
#   u'cut',
#   u'd',
#   u'd.',
#   u'dal-soo',
#   u'den',
#   u'dinner',
#   u'director',
#   u'doesnt',
#   u'dont',
#   u'doraemon',
#   u'ds',
#   u'e',
#   u'el',
#   u'entertainment',
#   u'entourage',
#   u'eun',
#   u'eun-gab',
#   u'euns',
#   u'everyones',
#   u'evil',
#   u'fuck',
#   u'gah',
#   u'get',
#   u'geun-young',
#   u'gong',
#   u'gu',
#   u'ha',
#   u'haena',
#   u'hahaha',
#   u'han-byul',
#   u'haneul',
#   u'haneulis',
#   u'haneuls',
#   u'hanuel',
#   u'hard',
#   u'harley',
#   u'has',
#   u'hed',
#   u'hell',
#   u'hes',
#   u'ho-jin',
#   u'ho-jins',
#   u'hwa-su',
#   u'hwa-sus',
#   u'hyukoh',
#   u'idea',
#   u'ideas',
#   u'ill',
#   u'im',
#   u'ims',
#   u'inside',
#   u'instagram',
#   u'ive',
#   u'j',
#   u'jeju',
#   u'ji-hyo',
#   u'jin',
#   'jj',
#   u'joey',
#   u'joeys',
#   u'joeyyou',
#   u'jong-seok',
#   u'joo-yeon',
#   u'joon',
#   u'joong-ki',
#   u'joons',
#   u'julien',
#   u'jung-woo',
#   u'kang',
#   u'kangs',
#   u'ki-bang',
#   u'kim',
#   u'koo',
#   u'korea',
#   u'kylo',
#   u'kyung',
#   u'lee',
#   u'legends',
#   u'lets',
#   u'little',
#   u'lol',
#   u'love',
#   u'luigi',
#   u'm',
#   u'ma',
#   u'manager',
#   u'mario',
#   u'marlon',
#   u'microbiology',
#   u'min-ho',
#   u'mom',
#   u'moon',
#   u'mountain',
#   u'mutant',
#   u'narcos',
#   u'nations',
#   u'nayoung',
#   'nn',
#   'nnps',
#   'nns',
#   u'oh',
#   u'ok',
#   u'olle',
#   u'oooh',
#   u'outside',
#   u'park',
#   u'parks',
#   u'per',
#   u'pftt',
#   u'prostate',
#   u'quinn',
#   u'rapper',
#   u'ren',
#   u'san',
#   u'seo-joon',
#   u'seung-hyo',
#   u'shes',
#   u'shocked',
#   u'simon',
#   u'sister',
#   u'so-hee',
#   u'somehow',
#   u'song',
#   u'soo-hyun',
#   u'soon',
#   u'star',
#   u'stripe',
#   u'sugar',
#   u'sung-kyun',
#   u'sung-min',
#   u'tarkovskys',
#   u'team',
#   u'terminator',
#   u'thats',
#   u'tiger',
#   u'trail',
#   u'turtle',
#   u'turtles',
#   u'upstairs',
#   u'venus',
#   u'war',
#   u'wars',
#   u'whats',
#   u'woman',
#   u'yang',
#   u'yangs',
#   u'yeezy',
#   u'yeon',
#   u'yoo',
#   u'young-jun',
#   u'youre'},
#  {u'adobe',
#   u'almost',
#   u'bastard',
#   u'dads',
#   u'eugene',
#   u'eugenes',
#   u'eve',
#   u'flash',
#   u'good',
#   u'hee',
#   u'hees',
#   u'hyun',
#   u'ill',
#   u'important',
#   u'ive',
#   u'jae',
#   u'jo',
#   u'jumi',
#   u'jumis',
#   u'kwang',
#   u'kyung',
#   u'life',
#   u'na',
#   'nn',
#   u'player',
#   u'remake',
#   u'rok',
#   u'shin',
#   u'sorry',
#   u'sponge',
#   u'su',
#   u'sung',
#   u'tae',
#   u'taes',
#   u'tasks',
#   u'three',
#   u'very',
#   u'were',
#   u'young',
#   u'youngs'},
#  {u'adobe',
#   u'adult',
#   u'agh',
#   u'aghhh',
#   u'aha',
#   u'ahhh',
#   u'ahn',
#   u'ahns',
#   u'ahnthe',
#   u'aieeeeeee',
#   u'ajumma',
#   u'ajummas',
#   u'ajusshi',
#   u'alarmed',
#   u'already',
#   u'annnnd',
#   u'annoyed',
#   u'armed',
#   u'assemblyman',
#   u'awww',
#   u'awwww',
#   u'b',
#   u'baby',
#   u'bae',
#   u'baek',
#   u'basically',
#   u'bears',
#   u'bernard',
#   u'bingo',
#   u'blanket',
#   u'blood',
#   u'bong-soo',
#   u'boss',
#   u'busker',
#   u'bwahaha',
#   u'bye',
#   u'cabbage',
#   u'cap',
#   u'chae',
#   u'chairman',
#   u'chi-soo',
#   u'child',
#   u'choi',
#   u'clark',
#   u'clocks',
#   u'contact',
#   u'crap',
#   u'crazy',
#   u'crush',
#   u'cut',
#   u'dad',
#   u'dads',
#   u'dae-sus',
#   u'damn',
#   u'dear',
#   u'detective',
#   u'did',
#   u'didnt',
#   u'dig',
#   u'direct',
#   u'dong-chul',
#   u'dont',
#   u'double',
#   u'download',
#   u'eager',
#   u'editor',
#   u'eek',
#   u'elder',
#   u'eternal',
#   u'fake',
#   u'fallaci',
#   u'father',
#   u'flash',
#   u'fogey',
#   u'gack',
#   u'gah',
#   u'gil-han',
#   u'go',
#   u'goddamn',
#   u'gramps',
#   u'grandpa',
#   u'grandpas',
#   u'grief',
#   u'group',
#   u'grumpy',
#   u'guh',
#   u'hacker',
#   u'haha',
#   u'hahaha',
#   u'haltingly',
#   u'han',
#   u'head',
#   u'heads',
#   u'healer',
#   u'hee',
#   u'heh',
#   u'hell',
#   u'hello',
#   u'hence',
#   u'hes',
#   u'holdings',
#   u'holy',
#   u'horan',
#   u'how',
#   u'howd',
#   u'huh',
#   u'hwang',
#   u'hwangs',
#   u'hyung',
#   u'ill',
#   u'im',
#   u'inside',
#   u'investigator',
#   u'island',
#   u'ive',
#   u'jae-gook',
#   u'jae-yoon',
#   u'jang',
#   u'jeil',
#   u'jeils',
#   u'jeon',
#   'jj',
#   u'jong-soos',
#   u'joo',
#   u'joon-seok',
#   u'joon-seokie',
#   u'joon-seoks',
#   u'jung-hoo',
#   u'kent',
#   u'ki-jung',
#   u'kim',
#   u'kims',
#   u'kudos',
#   u'lawyer',
#   u'learns',
#   u'lee',
#   u'linus',
#   u'listen',
#   u'love',
#   u'luna',
#   u'mama',
#   u'man',
#   u'manager',
#   u'melted',
#   u'merlin',
#   u'michael',
#   u'min-ja',
#   u'mom',
#   u'mommy',
#   u'moms',
#   u'monsters',
#   u'moon',
#   u'moon-ho',
#   u'moon-shik',
#   u'mooooooove',
#   u'morumoru',
#   u'mr.',
#   u'muahaha',
#   u'musician',
#   u'news',
#   u'newspaper',
#   u'newspapers',
#   'nn',
#   u'nooo',
#   u'noooo',
#   u'oh',
#   u'oha',
#   u'ohhh',
#   u'ohhhh',
#   u'ohhhhh',
#   u'okay',
#   u'old',
#   u'omega',
#   u'omegas',
#   u'omo',
#   u'oof',
#   u'ooh',
#   u'oppa',
#   u'oriana',
#   u'outside',
#   u'owner',
#   u'panicky',
#   u'papa',
#   u'park',
#   u'parks',
#   u'person',
#   u'pickpocket',
#   u'pirates',
#   u'plan',
#   u'player',
#   u'please',
#   u'powder',
#   u'pwahaha',
#   u'quick',
#   u'reporter',
#   u'rock',
#   u's',
#   u'samhan',
#   u'sang-soo',
#   u'see',
#   u'seo',
#   u'seung-gi',
#   u'shaken',
#   u'shed',
#   u'shes',
#   u'shit',
#   u'siiiigh',
#   u'similar',
#   u'slick',
#   u'slowly',
#   u'sneaky',
#   u'somebodys',
#   u'son',
#   u'spiderman',
#   u'spidey',
#   u'ss',
#   u'story',
#   u'superman',
#   u'taken',
#   u'teacher',
#   u'teachers',
#   u'team',
#   u'tears',
#   u'teenage',
#   u'thankfully',
#   u'thats',
#   u'theyve',
#   u'things',
#   u'todays',
#   u'too',
#   u'uncle',
#   u'unni',
#   u'utter',
#   u'wait',
#   u'were',
#   u'weve',
#   u'which',
#   u'who',
#   u'whoopsie',
#   u'will',
#   u'word',
#   u'wow',
#   u'yay',
#   u'yellow',
#   u'yeo',
#   u'yeon-hee',
#   u'yes',
#   u'yknow',
#   u'yoon',
#   u'yoons',
#   u'yoonthey',
#   u'youd',
#   u'youll',
#   u'young',
#   u'young-shin',
#   u'youre',
#   u'youve'},
#  {u'ace',
#   u'athlete',
#   u'award',
#   u'aww',
#   u'bachelor',
#   u'backstage',
#   u'bang',
#   u'bangs',
#   u'batter',
#   u'bin',
#   u'breakfast',
#   u'brother',
#   u'butit',
#   u'caught',
#   u'caveman',
#   u'cha',
#   u'chief',
#   u'choi',
#   u'class',
#   u'clueless',
#   u'coach',
#   u'couldve',
#   u'dad',
#   u'dads',
#   u'damn',
#   u'dare',
#   u'director',
#   u'does',
#   u'dont',
#   u'durrp',
#   u'eyes',
#   u'face',
#   u'father',
#   u'finally',
#   u'foggy',
#   u'furious',
#   u'further',
#   u'gaga',
#   u'girl',
#   u'god',
#   u'grandpa',
#   u'groo',
#   u'haha',
#   u'hahahaha',
#   u'han',
#   u'head',
#   u'hehehe',
#   u'hell',
#   u'heo',
#   u'hes',
#   u'him',
#   u'hurray',
#   u'hwang',
#   u'hyun',
#   u'hyun-woo',
#   u'id',
#   u'ill',
#   u'im',
#   u'inside',
#   u'jang',
#   u'jangs',
#   u'jeon',
#   u'jerk',
#   'jj',
#   u'jung-min',
#   u'kim',
#   u'lady',
#   u'lee',
#   u'left',
#   u'lets',
#   u'life',
#   u'lol',
#   u'lola',
#   u'lolas',
#   u'lul',
#   u'marriage',
#   u'me',
#   u'mi-kyung',
#   u'mi-rae',
#   u'min',
#   u'mom',
#   u'moms',
#   'nn',
#   'nns',
#   u'nooo',
#   u'noooo',
#   u'nope',
#   u'ohhh',
#   u'okay',
#   u'oreos',
#   u'papa',
#   u'park',
#   u'poor',
#   u'ppappa',
#   u'puppy',
#   u're',
#   u'really',
#   u'rehab',
#   u'right',
#   u'run',
#   u'ryu',
#   u'sa-rang',
#   u'seo',
#   u'shes',
#   u'shin',
#   u'single',
#   u'sloooowly',
#   u'stuck',
#   u'style',
#   u'suspicion',
#   u'tae-hee',
#   u'teacher',
#   u'tears',
#   u'thats',
#   u'too',
#   u'trial',
#   u'uncle',
#   u'uncowed',
#   u'uproar',
#   u'wait',
#   u'well',
#   u'were',
#   u'weve',
#   u'whew',
#   u'won',
#   u'woo-hyuk',
#   u'yeah',
#   u'yeol',
#   u'yeolhe',
#   u'yeols',
#   u'youre',
#   u'yu-ri',
#   u'yuri'},
#  {u'acoustic',
#   u'actress',
#   u'adobe',
#   u'afterward',
#   u'again',
#   u'along',
#   u'assistant',
#   u'aww',
#   u'awww',
#   u'bang',
#   u'burn',
#   u'byun',
#   u'cha',
#   u'choi',
#   u'chu',
#   u'company',
#   u'confession',
#   u'crazy',
#   u'cue',
#   u'curious',
#   u'cut',
#   u'dad',
#   u'dads',
#   u'director',
#   u'disorder',
#   u'dissociative',
#   u'does',
#   u'dont',
#   u'download',
#   u'easier',
#   u'edith',
#   u'enter',
#   u'eun',
#   u'everyone',
#   u'eyes',
#   u'fart',
#   u'female',
#   u'fine',
#   u'flash',
#   u'game',
#   u'global',
#   u'good',
#   u'grah',
#   u'group',
#   u'gu',
#   u'ha',
#   u'haha',
#   u'hana',
#   u'hanas',
#   u'hanashe',
#   u'hanawho',
#   u'hed',
#   u'hell',
#   u'hes',
#   u'hint',
#   u'honestly',
#   u'hong',
#   u'horrified',
#   u'huh',
#   u'hwang',
#   u'hyung',
#   u'id',
#   u'identity',
#   u'ill',
#   u'im',
#   u'island',
#   u'itd',
#   u'itll',
#   u'ive',
#   u'jeju',
#   u'ji-won',
#   'jj',
#   u'joo-wan',
#   u'jumei',
#   u'junior',
#   u'kerr',
#   u'kim',
#   u'kinda',
#   u'kthxbai',
#   u'lead',
#   u'leader',
#   u'lee',
#   u'liar',
#   u'likewise',
#   u'lips',
#   u'listen',
#   u'luckily',
#   u'mamamoo',
#   u'man',
#   u'manager',
#   u'mccrazerson',
#   u'mi-hyang',
#   u'min',
#   u'min-ji',
#   u'mins',
#   u'mir',
#   u'miranda',
#   u'mom',
#   u'moms',
#   'nn',
#   'nns',
#   u'non',
#   u'noona',
#   u'noooo',
#   u'oh',
#   u'ohn',
#   u'okay',
#   u'oppa',
#   u'orrrrr',
#   u'owwww',
#   u'park',
#   u'piafs',
#   u'piano',
#   u'player',
#   u'please',
#   u'poof',
#   u'poor',
#   u'pushy',
#   u'quick',
#   u'rain',
#   u'rainy',
#   u'reason',
#   u'relieved',
#   u'script',
#   u'seo-hoo',
#   u'shed',
#   u'shes',
#   u'shin',
#   u'sigh',
#   u'so-eun',
#   u'son',
#   u'sorry',
#   u'sunbae',
#   u'sung-jae',
#   u'super',
#   u'suzy',
#   u'taeyang',
#   u'taeyangs',
#   u'tandy',
# ...
#   u'hed',
#   u'heh',
#   u'hell',
#   u'help',
#   u'her',
#   u'hers',
#   u'hes',
#   u'hong-joo',
#   u'how',
#   u'hrm',
#   u'huh',
#   u'human',
#   u'hye-ryun',
#   u'hyung',
#   u'ill',
#   u'im',
#   u'indiana',
#   u'inside',
#   u'investigator',
#   u'jae-chan',
#   'jj',
#   u'jones',
#   u'jong-seok',
#   u'jung',
#   u'junior',
#   u'just',
#   u'kang',
#   u'killer',
#   u'kim',
#   u'king',
#   u'korea',
#   u'kyaa',
#   u'kyun-sang',
#   u'lawyer',
#   u'lee',
#   u'lie',
#   u'little',
#   u'lol',
#   u'me',
#   u'meets',
#   u'mom',
#   u'moms',
#   u'moon',
#   u'moons',
#   u'mouse',
#   u'my',
#   u'myung',
#   u'nam',
#   'nn',
#   'nns',
#   u'no',
#   u'noooo',
#   u'nooooo',
#   u'noooooo',
#   u'noooooooooo',
#   u'omg',
#   u'oof',
#   u'oppa',
#   u'page',
#   u'park',
#   u'patient',
#   u'pff',
#   u'pfffft',
#   u'pffft',
#   u'pfft',
#   u'phew',
#   u'phone',
#   u'please',
#   u'poop',
#   u'poor',
#   u'professor',
#   u'prosecutor',
#   u'public',
#   u'pwahahaha',
#   u'rage',
#   u'reporter',
#   u'right',
#   u'robin',
#   u'robins',
#   u'roomba',
#   u'run',
#   u'sang-yub',
#   u'santa',
#   u'santas',
#   u'scumbag',
#   u'shed',
#   u'shes',
#   u'sling',
#   u'smart',
#   u'smurf',
#   u'smurfs',
#   u'so-hyun',
#   u'sohn',
#   u'someone',
#   u'squeee',
#   u'suzys',
#   u'teehee',
#   u'thank',
#   u'turner',
#   u'vain',
#   u'valentines',
#   u'wait',
#   u'weird',
#   u'well',
#   u'whaaa',
#   u'whaaat',
#   u'which',
#   u'whoa',
#   u'wolverine',
#   u'woo-tak',
#   u'wow',
#   u'yay',
#   u'yeongdeok',
#   u'yoo-bum',
#   u'yoon',
#   u'zero'},
#  {u'access',
#   u'adobe',
#   u'afraid',
#   u'ah',
#   u'air',
#   u'alone',
#   u'already',
#   u'anyways',
#   u'apartment',
#   u'armed',
#   u'audio',
#   u'automobile',
#   u'automobiles',
#   u'bachs',
#   u'baek',
#   u'bar',
#   u'baseball',
#   u'basically',
#   u'bfrom',
#   u'bidangil',
#   u'bingo',
#   u'block',
#   u'blue',
#   u'board',
#   u'booya',
#   u'bora',
#   u'bravo',
#   u'bromance',
#   u'bwahaha',
#   u'bwahahah',
#   u'byung',
#   u'calls',
#   u'calmly',
#   u'camera',
#   u'case',
#   u'catch',
#   u'cha',
#   u'chan',
#   u'checkmate',
#   u'chi',
#   u'choi',
#   u'choianymore',
#   u'choibecause',
#   u'christine',
#   u'chun',
#   u'city',
#   u'clearly',
#   u'cliffhanger',
#   u'command',
#   u'cow',
#   u'coworker',
#   u'cows',
#   u'crap',
#   u'crazy',
#   u'cripes',
#   u'cyber',
#   u'dae',
#   u'daehan',
#   u'daerim',
#   u'dam',
#   u'dang',
#   u'danggit',
#   u'daniel',
#   u'dark',
#   u'death',
#   u'delete',
#   u'department',
#   u'detective',
#   u'did',
#   u'die',
#   u'director',
#   u'do',
#   u'doctor',
#   u'dong',
#   u'dont',
#   u'dreams',
#   u'dude',
#   u'electric',
#   u'electrics',
#   u'ensue',
#   u'enter',
#   u'eun',
#   u'eung',
#   u'euns',
#   u'everyone',
#   u'evil',
#   u'eye',
#   u'eyes',
#   u'fair',
#   u'fast',
#   u'fat',
#   u'file',
#   u'fine',
#   u'flash',
#   u'flashback',
#   u'food',
#   u'fund',
#   u'funny',
#   u'gah',
#   u'ghost',
#   u'girl',
#   u'girls',
#   u'go',
#   u'gosh',
#   u'grandpa',
#   u'group',
#   u'groups',
#   u'gu',
#   u'guess',
#   u'gyeonggi',
#   u'gyun',
#   u'gyuns',
#   u'ha',
#   u'hacking',
#   u'hades',
#   u'hae',
#   u'haha',
#   u'hahah',
#   u'hahaha',
#   u'han',
#   u'hang',
#   u'harvest',
#   u'headquarters',
#   u'hee',
#   u'heeand',
#   u'heeeeee',
#   u'heehee',
#   u'hees',
#   u'hehe',
#   u'hell',
#   u'hellooooo',
#   u'hence',
#   u'hero',
#   u'hes',
#   u'hey',
#   u'high',
#   u'hmm',
#   u'hmmm',
#   u'ho',
#   u'holy',
#   u'honestly',
#   u'honey',
#   u'hoodie',
#   u'hoodies',
#   u'house',
#   u'hurry',
#   u'hush',
#   u'hye',
#   u'hyo',
#   u'hyuk',
#   u'hyun',
#   u'hyundoes',
#   u'hyuns',
#   u'id',
#   u'il',
#   u'ill',
#   u'ils',
#   u'im',
#   u'imagine',
#   u'inju',
#   u'inside',
#   u'inspector',
#   u'ip',
#   u'isnt',
#   u'ive',
#   u'ivy',
#   u'jae',
#   u'jaes',
#   u'jang',
#   u'jeongs',
#   u'ji',
#   u'jin',
#   u'jins',
#   'jj',
#   u'jo',
#   u'jong',
#   u'joo',
#   u'joon',
#   u'joong',
#   u'joons',
#   u'joontoo',
#   u'joonwill',
#   u'jooreally',
#   u'jooreallylikes',
#   u'joos',
#   u'jun',
#   u'jung',
#   u'jungs',
#   u'juns',
#   u'junthat',
#   u'junto',
#   u'kaedejun',
#   u'kang',
#   u'kangs',
#   u'ki',
#   u'kid',
#   u'killer',
#   u'kim',
#   u'kims',
#   u'know',
#   u'korea',
#   u'korean',
#   u'kudos',
#   u'kwak',
#   u'kwon',
#   u'kyun',
#   u'kyung',
#   u'leader',
#   u'leagues',
#   u'lee',
#   u'lets',
#   u'liar',
#   u'look',
#   u'luckily',
#   u'lucky',
#   u'luna',
#   u'mad',
#   u'make',
#   u'man',
#   u'media',
#   u'melissa',
#   u'mi',
#   u'min',
#   u'mindefinitelyhas',
#   u'mins',
#   u'mis',
#   u'miwantsto',
#   u'money',
#   u'moon',
#   u'moondid',
#   u'moons',
#   u'mr.',
#   u'myung',
#   u'nam',
#   u'nams',
#   'nn',
#   'nnps',
#   u'noh',
#   u'nohs',
#   u'nothing',
#   u'officer',
#   u'oh',
#   u'ok',
#   u'oooh',
#   u'ooooh',
#   u'original',
#   u'ost',
#   u'otherwise',
#   u'outside',
#   u'palace',
#   u'paradise',
#   u'park',
#   u'pfft',
#   u'phantom',
#   u'pick',
#   u'player',
#   u'please',
#   u'political',
#   u'poor',
#   u'professor',
#   u'prosecutor',
#   u'ra',
#   u'ram',
#   u'ramen',
#   u'rams',
#   u'ranch',
#   u'ras',
#   u'rather',
#   u'resort',
#   u'resorts',
#   u'revenge',
#   u'ri',
#   u'right',
#   u'ris',
#   u'run',
#   u'sa',
#   u'safe',
#   u'safety',
#   u'sang',
#   u'scared',
#   u'school',
#   u'scientist',
#   u'screwed',
#   u'se',
#   u'secret',
#   u'security',
#   u'sekang',
#   u'sekangs',
#   u'seo',
#   u'seon',
#   u'seong',
#   u'seos',
#   u'seoul',
#   u'seung',
#   u'sheesh',
#   u'shes',
#   u'shifty',
#   u'shin',
#   u'shins',
#   u'slowly',
#   u'slush',
#   u'smooth',
#   u'so',
#   u'sol',
#   u'sols',
#   u'som',
#   u'someone',
#   u'soo',
#   u'sook',
#   u'sooks',
#   u'soos',
#   u'sorry',
#   u'steganography',
#   u'story',
#   u'storys',
#   u'stuck',
#   u'study',
#   u'style0426',
#   u'sub',
#   u'success',
#   u'suk',
#   u'suks',
#   u'sung',
#   u'system',
#   u'tae',
#   u'teacher',
#   u'team',
#   u'tech',
#   u'techs',
#   u'telecom',
#   u'thank',
#   u'thankfully',
#   u'thats',
#   u'theyre',
#   u'though',
#   u'top',
#   u'touche',
#   u'tower',
#   u'townhouses',
#   u'trample',
#   u'true',
#   u'twinkle',
#   u'twitter',
#   u'uh',
#   u'uhm',
#   u'um',
#   u'uncle',
#   u'uncles',
#   u'usb',
#   u'vans',
#   u'victory',
#   u'video',
#   u'villa',
#   u'virus',
#   u'volunteer',
#   u'wait',
#   u'wang',
#   u'well',
#   u'weve',
#   u'whaaaat',
#   u'whats',
#   u'which',
#   u'whoa',
#   u'wi',
#   u'won',
#   u'wons',
#   u'woo',
#   u'woo-young',
#   u'woo.sang',
#   u'woohoo',
#   u'woos',
#   u'word',
#   u'worried',
#   u'wow',
#   u'y2k',
#   u'yang',
#   u'yangs',
#   u'yeah',
#   u'yeom',
#   u'yeon',
#   u'yeons',
#   u'yep',
#   u'yippee',
#   u'yo',
#   u'yoo',
#   u'yoon',
#   u'yoons',
#   u'young',
#   u'young/woo-young',
#   u'youngs',
#   u'youngwho',
#   u'youre'},
#  {u'adult',
#   u'again',
#   u'ahn',
#   u'ahns',
#   u'almost',
#   u'angry',
#   u'aww',
#   u'awww',
#   u'baby',
#   u'back',
#   u'bear',
#   u'blunt',
#   u'butler',
#   u'calmly',
#   u'cha',
#   u'chairman',
#   u'choi',
#   u'chun',
#   u'cockroach',
#   u'cranky',
#   u'curious',
#   u'cut',
#   u'cute',
#   u'dad',
#   u'dads',
#   u'daniel',
#   u'detective',
#   u'dog',
#   u'dont',
#   u'doo-soo',
#   u'eun-ho',
#   u'exhausted',
#   u'famous',
#   u'fine',
#   u'fix',
#   u'gah',
#   u'geez',
#   u'go',
#   u'god',
#   u'grandma',
#   u'grumpy',
#   u'haha',
#   u'heart',
#   u'hed',
#   u'hee',
#   u'hello',
#   u'hes',
#   u'hilariously',
#   u'hong-do',
#   u'horrified',
#   u'housekeeper',
#   u'huggy',
#   u'hurt',
#   u'hwang',
#   u'il-seok',
#   u'ill',
#   u'im',
#   u'inside',
#   u'island',
#   u'jang',
#   u'jeju',
#   u'jerk',
#   'jj',
#   u'kill',
#   u'lamp',
#   u'later',
#   u'lee',
#   u'lets',
#   u'love',
#   u'luckily',
#   u'madam',
#   u'meryl',
#   u'mom',
#   u'moms',
#   u'napoleon',
#   'nn',
#   u'nobody',
#   u'oblivious',
#   u'oh',
#   u'ohs',
#   u'okay',
#   u'oof',
#   u'ooo',
#   u'ooohh',
#   u'oppa',
#   u'park',
#   u'patience',
#   u'poor',
#   u'prince',
#   u'rapunzel',
#   u'rawr',
#   u'really',
#   u'right',
#   u'riiiight',
#   u'run',
#   u'se-ro',
#   u'sheesh',
#   u'shes',
#   u'sick',
#   u'sleep',
#   u'smart',
#   u'soon',
#   u'stop',
#   u'streep',
#   u'thank',
#   u'thrown',
#   u'voice-of-reason',
#   u'well',
#   u'who',
#   u'yang',
#   u'yi-seok'},
#  {u'adobe',
#   u'adult',
#   u'ae',
#   u'aethough',
#   u'again',
#   u'angry',
#   u'awesome',
#   u'awkward',
#   u'aww',
#   u'awww',
#   u'bad',
#   u'bastard',
#   u'best',
#   u'birthday',
#   u'brother',
#   u'butler',
#   u'byun',
#   u'choi',
#   u'choice',
#   u'chois',
#   u'coincidentally',
#   u'congressman',
#   u'crazy',
#   u'cut',
#   u'dad',
#   u'dang',
#   u'director',
#   u'doctor',
#   u'dont',
#   u'double',
#   u'dude',
#   u'eun-ha',
#   u'eun-has',
#   u'evil',
#   u'father',
#   u'flash',
#   u'furious',
#   u'further',
#   u'girl',
#   u'god',
#   u'gossip',
#   u'happiness',
#   u'happy',
#   u'hed',
#   u'hee',
#   u'hell',
#   u'hes',
#   u'hmmm',
#   u'ill',
#   u'im',
#   u'inside',
#   u'jerkface',
#   u'ji-sook',
#   u'ji-sooks',
#   'jj',
#   u'just',
#   u'kill',
#   u'kim',
#   u'later',
#   u'lies',
#   u'life',
#   u'love',
#   u'luckily',
#   u'maid',
#   u'manager',
#   u'mask',
#   u'me',
#   u'memory',
#   u'mi-yeon',
#   u'million',
#   u'min',
#   u'min-woo',
#   u'mom',
#   u'moms',
#   u'nam-chul',
#   u'napoleon',
#   u'nearby',
#   u'next',
#   'nn',
#   u'nobody',
#   u'noona',
#   u'okay',
#   u'oooh',
#   u'otherwise',
#   u'papa',
#   u'player',
#   u'poor',
#   u'pushed',
#   u'scar',
#   u'seo',
#   u'shed',
#   u'shes',
#   u'shim',
#   u'shims',
#   u'sir',
#   u'soon',
#   u'stepmom',
#   u'stepmoms',
#   u'stop',
#   u'stuck',
#   u'su',
#   u'subtlety',
#   u'thank',
#   u'thing',
#   u'time',
#   u'trap',
#   u'unhappy',
#   u'vacancy',
#   u'very',
#   u'wait',
#   u'wake',
#   u'whats',
#   u'which',
#   u'whoa',
#   u'will',
#   u'won',
#   u'worst',
#   u'yang',
#   u'yeon-soo',
#   u'yu-jin'},
#  {u'aftera',
#   u'again',
#   u'ajusshi',
#   u'apologetically',
#   u'ara',
#   u'auntie',
#   u'aww',
#   u'awww',
#   u'between',
#   u'bless',
#   u'brought',
#   u'chairman',
#   u'chef',
#   u'contract',
#   u'cut',
#   u'dad',
#   u'daddy',
#   u'dads',
#   u'doc',
#   u'does',
#   u'dont',
#   u'downstairs',
#   u'dryly',
#   u'eager',
#   u'eun-sung',
#   u'eww',
#   u'fairy',
#   u'father',
#   u'frantic',
#   u'furious',
#   u'geez',
#   u'go',
#   u'grandma',
#   u'gratitude',
#   u'gruff',
#   u'guhhhh',
#   u'haha',
#   u'hahaha',
#   u'han',
#   u'hans',
#   u'happiness',
#   u'hed',
#   u'hee',
#   u'hell',
#   u'hes',
#   u'hey',
#   u'ho-joon',
#   u'hope',
#   u'hurt',
#   u'hye-soo',
#   u'iam',
#   u'ill',
#   u'im',
#   u'inside',
#   u'island',
#   u'ive',
#   u'jealousy',
#   u'jeju',
#   'jj',
#   u'joo-yeon',
#   u'kang',
#   u'kim',
#   u'later',
#   u'lee',
#   u'liver',
#   u'lol',
#   u'lols',
#   u'love',
#   u'luckily',
#   u'madam',
#   u'manager',
#   u'marriage',
#   u'miniature',
#   u'mom',
#   u'moms',
#   u'moved',
#   u'na-yoon',
#   u'night',
#   'nn',
#   u'nooo',
#   u'nooooo',
#   u'ohhh',
#   u'ohmyguhh',
#   u'okay',
#   u'oppa',
#   u'ouch',
#   u'outside',
#   u'poor',
#   u'promise',
#   u'ramyun',
#   u'scared',
#   u'server',
#   u'shark',
#   u'sharks',
#   u'shed',
#   u'shes',
#   u'slow',
#   u'smooth',
#   u'snip',
#   u'snooty',
#   u'soo-chang',
#   u'stranded',
#   u'sunnier',
#   u'theyre',
#   u'tone',
#   u'touche',
#   u'true',
#   u'uncle',
#   u'unsteady',
#   u'upbeat',
#   u'upset',
#   u'well',
#   u'woken',
#   u'wow',
#   u'yoon',
#   u'yoons'},
#  {u'abroad',
#   u'afterward',
#   u'again',
#   u'air',
#   u'airport',
#   u'annie',
#   u'annies',
#   u'annieshe',
#   u'annoyed',
#   u'asia',
#   u'aunt',
#   u'beautiful',
#   u'choi',
#   u'creep',
#   u'creepy',
#   u'curiouser',
#   u'cut',
#   u'dad',
#   u'dads',
#   u'damn',
#   u'daww',
#   u'did',
#   u'do-woo',
#   u'dont',
#   u'dude',
#   u'eager',
#   u'eun-woo',
#   u'far',
#   u'feeling',
#   u'flustered',
#   u'frantic',
#   u'furious',
#   u'gah',
#   u'go',
#   u'gosh',
#   u'grandma',
#   u'grandmas',
#   u'grimly',
#   u'hah',
#   u'haha',
#   u'han',
#   u'haneul',
#   u'hed',
#   u'hell',
#   u'hes',
#   u'hye-won',
#   u'hyo-eun',
#   u'id',
#   u'ill',
#   u'im',
#   u'incheon',
#   u'island',
#   u'itll',
#   u'ive',
#   u'jang',
#   u'je-ah',
#   u'jeju',
#   u'ji-eun',
#   u'jin-suk',
#   'jj',
#   u'joo-yeon',
#   u'kev',
#   u'kevin',
#   u'kim',
#   u'korean',
#   u'kuala',
#   u'lee',
#   u'legs',
#   u'lumpur',
#   u'mary',
#   u'marys',
#   u'master',
#   u'min',
#   u'mom',
#   u'moon',
#   u'moons',
#   u'mother',
#   u'mr.',
#   'nn',
#   'nnps',
#   'nns',
#   u'nooo',
#   u'ohhh',
#   u'ohmigod',
#   u'okay',
#   u'ooh',
#   u'outside',
#   u'park',
#   u'parks',
#   u'pilot',
#   u'please',
#   u'right',
#   u'river',
#   u'school',
#   u'seo',
#   u'shed',
#   u'shes',
#   u'shut',
#   u'soon',
#   u'sorry',
#   u'su-ah',
#   u'suk',
#   u'suks',
#   u'suspicious',
#   u'take',
#   u'uncle',
#   u'waterfront',
#   u'way',
#   u'were',
#   u'woman',
#   u'worried',
#   u'yeah',
#   u'yeesh',
#   u'young-sook'},
#  {u'adobe',
#   u'afterward',
#   u'again',
#   u'ahn',
#   u'airhead',
#   u'alarmed',
#   u'alexander',
#   u'already',
#   u'andromeda',
#   u'angry',
#   u'anne',
#   u'are',
#   u'audio',
#   u'austens',
#   u'barbershop',
#   u'beat',
#   u'bedroom',
#   u'bet',
#   u'bi-yin',
#   u'big',
#   u'biker',
#   u'bleaaah',
#   u'bora',
#   u'boss',
#   u'boxer',
#   u'bridget',
#   u'briefs',
#   u'bro',
#   u'brother',
#   u'brown',
#   u'bury',
#   u'cake',
#   u'cash',
#   u'caught',
#   u'che',
#   u'chocula',
#   u'choi',
#   u'cinderella',
#   u'city',
#   u'cmon',
#   u'comes',
#   u'count',
#   u'couples',
#   u'coward',
#   u'creep',
#   u'creeps',
#   u'creepy',
#   u'curiosity',
#   u'cute',
#   u'dad',
#   u'daddy',
#   u'dads',
#   u'dal',
#   u'dallaeban',
#   u'darcy',
#   u'dawny',
#   u'disturb',
#   u'divorce',
#   u'dong',
#   u'dont',
#   u'download',
#   u'drunk',
#   u'dude',
#   u'emma',
#   u'encouraged',
#   u'eyes',
#   u'fine',
#   u'first',
#   u'flash',
#   u'flashback',
#   u'gadget',
#   u'goodbye',
#   u'grrrlp',
#   u'guevara',
#   u'haha',
#   u'hed',
#   u'hell',
#   u'help',
#   u'hes',
#   u'holladang',
#   u'hot',
#   u'how',
#   u'hwang',
#   u'hye-sun',
#   u'hyun-soo',
#   u'hyun-sung',
#   u'id',
#   u'ill',
#   u'im',
#   u'inside',
#   u'inspector',
#   u'island',
#   u'itll',
#   u'ive',
#   u'j',
#   u'jane',
#   u'jas',
#   u'jeju',
#   u'jeopardy',
#   'jj',
#   u'jones',
#   u'jung',
#   u'kang-hyun',
#   u'keep',
#   u'keke',
#   u'ki-woong',
#   u'kim',
#   u'king',
#   u'kyung-hwan',
#   u'la',
#   u'lbbbth',
#   u'lee',
#   u'lets',
#   u'life',
#   u'live',
#   u'lois',
#   u'loner',
#   u'love',
#   u'lucite',
#   u'man',
#   u'marriage',
#   u'marriages',
#   u'mars',
#   u'maybee',
#   u'me',
#   u'met',
#   u'metizens',
#   u'mom',
#   u'moment',
#   u'moms',
#   u'mother',
#   u'mr.',
#   u'night',
#   'nn',
#   u'okay',
#   u'one',
#   u'ones',
#   u'oops',
#   u'ost',
#   u'park',
#   u'peace',
#   u'perplexed',
#   u'player',
#   u'please',
#   u'pluto',
#   u'poor',
#   u'psst',
#   u'queen',
#   u'rapunzels',
#   u'rich',
#   u'rotten',
#   u'ryohei',
#   u'sexy',
#   u'shed',
#   u'shes',
#   u'sick',
#   u'smile',
#   u'snow',
#   u'solo',
#   u'somebodys',
#   u'sorry',
#   u'source',
#   u'spring',
#   u'squeeeee',
#   u'stereo',
#   u'stung',
#   u'superman',
#   u'sweet',
#   u'tai',
#   u'tarzan',
#   u'tokki',
#   u'tragedy',
#   u'true',
#   u'urban',
#   u'waltz',
#   u'weird',
#   u'whats',
#   u'which',
#   u'white',
#   u'wifey',
#   u'will',
#   u'women',
#   u'word',
#   u'work',
#   u'worried',
#   u'worst',
#   u'yeon-woo',
#   u'yoon',
#   u'youre',
#   u'youve',
#   u'yowza',
#   u'zza',
#   u'zzzhrr'},
#  {u'again',
#   u'aha',
#   u'ajusshi',
#   u'alas',
#   u'alcohol',
#   u'aloud',
#   u'andwere',
#   u'anyway',
#   u'awkward',
#   u'aww',
#   u'baek-ho',
#   u'baek-hos',
#   u'bear',
#   u'berras',
#   u'boss',
#   u'box',
#   u'boy',
#   u'boyfriend',
#   u'buffoon',
#   u'busan',
#   u'candy',
#   u'check',
#   u'christmas',
#   u'clearly',
#   u'coach',
#   u'couple',
#   u'cruise',
#   u'cut',
#   u'cute',
#   u'dad',
#   u'daddy',
#   u'dads',
#   u'daisakusen',
#   u'damn',
#   u'death',
#   u'didnt',
#   u'doctor',
#   u'dont',
#   u'double',
#   u'drunk',
#   u'dude',
#   u'dvd',
#   u'ecstatic',
#   u'enraged',
#   u'esther',
#   u'eve',
#   u'fantasy',
#   u'father',
#   u'flash',
#   u'forget',
#   u'freeze',
#   u'future',
#   u'grandpa',
#   u'grandpas',
#   u'greedy',
#   u'grumpy',
#   u'haha',
#   u'hahaha',
#   u'ham',
#   u'hard',
#   u'heart',
#   u'hed',
#   u'helen',
#   u'hell',
#   u'hes',
#   u'hey',
#   u'hilariously',
#   u'hitter',
#   u'hmm',
#   u'how',
#   u'huzzah',
#   u'ill',
#   u'im',
#   u'inside',
#   u'island',
#   u'issues',
#   u'ive',
#   u'jeju',
#   u'jerry',
#   u'jin-won',
#   u'jinwon',
#   'jj',
#   u'jonsen',
#   u'kang',
#   u'kim',
#   u'kwon',
#   u'leapt',
#   u'lee',
#   u'lesson',
#   u'life',
#   u'listen',
#   u'little',
#   u'maguire',
#   u'merry',
#   u'mission',
#   u'mom',
#   u'moms',
#   u'mother',
#   u'moved',
#   u'movie',
#   u'mr.',
#   'nn',
#   u'odd',
#   u'okay',
#   u'oof',
#   u'ooh',
#   u'operation',
#   u'pandoras',
#   u'perfect',
#   u'pervert',
#   u'pfffftt',
#   u'plan',
#   u'poor',
#   u'proposal',
#   u'pssh',
#   u'random',
#   u'ready',
#   u'regret',
#   u'renovatio',
#   u'sang-hoon',
#   u'santa',
#   u'shes',
#   u'shop',
#   u'sigh',
#   u'silly',
#   u'sky',
#   u'smaaccckk',
#   u'smart',
#   u'snack',
#   u'snow',
#   u'someone',
#   u'song',
#   u'soon',
#   u'sorry',
#   u'stairway',
#   u'stay',
#   u'swooon',
#   u'ticket',
#   u'tickets',
#   u'tom',
#   u'troy',
#   u'ump',
#   u'university',
#   u'valentines',
#   u'wahhh',
#   u'wait',
#   u'welcome',
#   u'were',
#   u'weve',
#   u'whats',
#   u'which',
#   u'who',
#   u'whoops',
#   u'work',
#   u'yi-seul',
#   u'yogi',
#   u'yoo',
#   u'yoo-bin',
#   u'young',
#   u'yourein'}]

# %% [markdown]
# ### NER using spaCy

# %%
# set up the list holding all the persons identified
all_persons = []

# loop through each show, identify named entities - persons
for show_num in range(len(recaps)):
    # load each show's recaps into spacy nlp model
    recap = nlp_spacy(recaps.values()[show_num]) 
    persons = {ent.text.replace('.', '').strip() for ent in recap.ents 
               if (ent.label_ in ['PERSON', 'GPE', 'ORG', 'NORP', 'FACILITY', 'PRODUCT', 'WORK_OF_ART']) 
               and not (ent.text.isspace())}
    # make lowercase, don't use words with spaces or with special characters
    persons = {part.lower() for word in persons for part in word.split('-') if part.isalpha()}
    m_persons = list(persons) + [word+'s' for word in persons]
    all_persons.append(m_persons)

# this is the names that we should exclude

# %% [markdown]
# #### Combine NLTK & spaCy NER for best results
# After trying out both, it seems like they both miss things out - it was best to combine them

# %%
# combine both nltk and spacy NER for best results!!
name_stop = [list(set(show + list(all_ne_nltk[i]))) for i, show in enumerate(all_persons)]

# %% [markdown]
# ### more preprocessing
#
# POS tagging, lemmatization, cleaning, forming bigram tokens

# %%
# define function to convert POS tag into a form that Wordnet can recognise
def pos_to_wordnet(tag):
    '''convert from nltk tag to wordnet tag'''

    if tag.startswith('J'):
        wn = 'a'
    elif tag.startswith('R'):
        wn = 'r'
    elif tag.startswith('V'):
        wn = 'v'
    else:
        wn = 'n' # the default
    return wn

# %%
# remove stopwords, punctuation, remove words that only have 1 letter, remove names, convert POS tag from NLTK to wordnet format
stop = stopwords.words('english')
stop = list(set(stop + [word.replace("'", '') for word in stop])) + ['thats', 'hed', 'hes'] # remove the apostrophes, append to stop words list
tokenized_clean = [[(word[0].strip().lower(), pos_to_wordnet(word[1])) for word in show 
                    if ((word[0].strip().lower() not in stop) and (word[0].lower() not in list(name_stop[i]))) # use all_ne_nltk OR all_persons
                    if (word[0].isalpha()) and (len(word[0]) >2)] # or (('-' in word) and word !='-')
                    for i, show in enumerate(tagged)]
# print len(tokenized_clean)
# print len(tokenized_clean[0]), len(tokenized_clean[1])
# consider only removing names for that particular show....

# %%
# lemmatise - choose lemmatizer instead of stemmer as stemming is too harsh, 
# especially for korean words which we want to keep intact
stemmer = WordNetLemmatizer()
tokenized_clean_lem = [[stemmer.lemmatize(word[0], word[1]) for word in show] 
                        for show in tokenized_clean]
# print len(tokenized_clean_lem[0]), len(tokenized_clean_lem[1])

# after lemmatisation, check for stop words again
tokenized_clean_lem = [[word for word in show if word not in stop]
                       for show in tokenized_clean_lem]

# %%
# create bigrams too
bigrms = [list(nltk.bigrams(show)) for show in tokenized_clean_lem]
bigrms = [[' '.join(list(bi)) for bi in show] for show in bigrms]
bigrms_clean_lem = [show + tokenized_clean_lem[i] for i, show in enumerate(bigrms)]

# %% [markdown]
# ### GENSIM
# Explore several methods to do topic modelling using GENSIM.

# %%
# create gensim dictionary & bag of words corpus - FOR BIGRAMS
dictionary = Dictionary(bigrms_clean_lem)
corpus = [dictionary.doc2bow(show) for show in bigrms_clean_lem]

# %%
def topwords(bow, dictionary, num_words=10):
    '''displays the top number of words as specified by num_words 
    using the bow (word_id, count/freq)'''
    
    bow_doc = sorted(bow, key=lambda w: w[1], reverse=True)
    for word_id, word_count in bow_doc[:num_words]:
        print dictionary.get(word_id), word_count

# %% [markdown]
# #### Method 1: bag-of-words
# As expected, themes identified sucked. There are many recurring words in a recap. e.g. "asks", "like", "back", etc.

# %%
# # using basic bag-of-words: print 5 most common words
# for i, show in enumerate(shows):
#     print '------', show.upper()
#     topwords(corpus[i], dictionary, num_words=5)

# %% [markdown]
# #### Method 2: TF-IDF
# TF-IDF = term frequency - inverse document frequency
#
# term frequency = raw count of a term in a document
# inverse doc frequency = log of total no of documents in corpus / number of documents where term appears
#
# Because it filters out words that occur frequently over the entire corpus, it addresses the problem with bag-of-words.
#
# - common words are penalised, rare words gain importance
#
# Actually this was pretty good!

# %%
# %%time 
# tf-idf
tfidf = TfidfModel(corpus)
for i, show in enumerate(shows):
    print '------', show.upper()
    topwords(tfidf[corpus[i]], dictionary, num_words=10)
    
# getting a lot of names of people... need to remove them - removed via NER
# should tune word lemmatizer
# should tune NER, consider n-grams - e.g. serial & killer should be serial killer

# %%
# compare similarity of docs
index = similarities.MatrixSimilarity(tfidf[corpus])

# %%
df_sims = pd.DataFrame(list(index))

# %%
sims = pd.DataFrame({'shownames': shows, 'similarity':index[tfidf[corpus[0]]]})
sims.sort_values('similarity', ascending=False)
# for i in range(num_shows):
#     print sims[i], shownames[i]

# %%
# save as a pickle file
version = 'v8-386-bigram'
to_pickle = ['df_sims', 'corpus', 'tfidf', 'dictionary', 'shows']

for var in to_pickle:
    pickle.dump(eval(var), open('tfidf_files/{}_{}.pkl'.format(var, version), 'wb'))

# %%
# save show indexing as pickle file
pickle.dump(sims.shownames, open('tfidf_files/show_mapping.pkl', 'wb'))

# %% [markdown]
# ### Method 3: LDA
#
# not so great for this application, because:
# - not able to predict how many topics ahead of time
# - the topics are not named, just grouped
# - not able to get features of a particular show

# %%
# %%time 
# # LDA - over all shows - doesn't work very well, even when we put in the tf-idf bow
# tfidf_corpus = tfidf[corpus]
# lda = LdaModel(tfidf_corpus, num_topics=num_shows, id2word=dictionary, passes=20)

# # print
# for topic in lda.print_topics():
#     print topic

# %%
# %%time 
# # compare with LDA multicore
# ldamulti = LdaMulticore(corpus, num_topics=3, id2word=dictionary, passes=50, workers=3)

# # doesn't seem like it is faster at all... O.O KIV for next time

# # print
# print ldamulti.print_topics()

# %% [markdown]
# In general, TF-IDF looks best. Choose to go with it for feature extraction of the theme of a particular show.
